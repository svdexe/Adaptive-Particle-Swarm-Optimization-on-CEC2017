# %%
import sys
sys.path.insert(1, '/kaggle/working/cec2017-py')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import cec2017.functions as functions

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
 
def standard_pso(objective_func, dim, num_particles, max_iter, bounds=(-100, 100)):
    # Initialize particles and velocities
    particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
    velocities = np.random.uniform(-1, 1, (num_particles, dim))
    
    # Initialize personal best and global best
    pbest = particles.copy()
    pbest_fitness = np.array([objective_func(p) for p in pbest])
    gbest = pbest[np.argmin(pbest_fitness)]
    gbest_fitness = np.min(pbest_fitness)
    
    # PSO parameters (constant for standard PSO)
    w = 0.7  # Inertia weight
    c1 = 2  # Cognitive parameter
    c2 = 2  # Social parameter
    
    convergence = []
    
    # Main PSO loop
    for iteration in range(max_iter):
        # Update velocities
        r1, r2 = np.random.rand(2)
        velocities = (w * velocities
                      + c1 * r1 * (pbest - particles)
                      + c2 * r2 * (gbest - particles))
        
        # Update particles
        particles += velocities
        
        # Apply bounds
        particles = np.clip(particles, bounds[0], bounds[1])
        
        # Evaluate fitness
        fitness = np.array([objective_func(p) for p in particles])
        
        # Update personal best
        improved = fitness < pbest_fitness
        pbest[improved] = particles[improved]
        pbest_fitness[improved] = fitness[improved]
        
        # Update global best
        if np.min(fitness) < gbest_fitness:
            gbest = particles[np.argmin(fitness)]
            gbest_fitness = np.min(fitness)
        
        convergence.append(gbest_fitness)
        
        # Print progress (commented out to match your code)
        if iteration % 250 == 0:
            pass
            #print(f"Iteration {iteration}: Best fitness = {gbest_fitness:.6f}")
    
    return gbest, gbest_fitness, w, c1, c2, convergence


# Set parameters
dim = 50
num_particles = 100
max_iter = 1000
bounds = (-100, 100)
num_iterations = 11

# List to store results for all functions
all_results = []

# Test all 30 functions
for func_num in range(21, 31):
    print(f"\nTesting Function {func_num}")
    
    # Get the CEC2017 function
    cec_function = getattr(functions, f'f{func_num}')
    
    # Create a wrapper function to handle the different input format
    def objective_func(x):
        return cec_function(x.reshape(1, -1))[0]
    
    # Run iterations
    results = []
    distances = []
    all_convergences = []
    for i in range(num_iterations):
        best_solution, best_fitness, final_w, final_c1, final_c2, convergence = standard_pso(objective_func, dim, num_particles, max_iter, bounds)
        distance = abs(best_fitness - func_num * 100)
        results.append(best_fitness)
        distances.append(distance)
        all_convergences.append(convergence)
        #print(f"Run {i+1}: Final fitness = {best_fitness:.6f}, Distance from optimum = {distance:.6f}, Final parameters: w = {final_w:.3f}, c1 = {final_c1:.3f}, c2 = {final_c2:.3f}")
    
    # Calculate statistics
    mean_fitness = np.mean(results)
    median_fitness = np.median(results)
    best_fitness = np.min(results)
    worst_fitness = np.max(results)
    std_fitness = np.std(results)
    best_distance = np.min(distances)
    worst_distance = np.max(distances)
    mean_distance = np.mean(distances)
    median_distance = np.median(distances)
    std_distance = np.std(distances)
    
    # Store results for this function
    all_results.append([best_fitness, worst_fitness, median_fitness, mean_fitness, std_fitness])
    
    print(f"\nFunction {func_num} optimization complete:")
    print(f"Mean fitness: {mean_fitness:.6f}")
    print(f"Median fitness: {median_fitness:.6f}")
    print(f"Best fitness: {best_fitness:.6f}")
    print(f"Worst fitness: {worst_fitness:.6f}")
    print(f"Standard deviation: {std_fitness:.6f}")
    print(f"Best distance from optimum (ERROR): {best_distance:.6f} / {best_distance:.6E}")
    print(f"Worst distance from optimum (ERROR): {worst_distance:.6f} / {worst_distance:.6E}")
    print(f"Mean distance from optimum (ERROR): {mean_distance:.6f} / {mean_distance:.6E}")
    print(f"Median distance from optimum (ERROR): {median_distance:.6f} / {median_distance:.6E}")
    print(f"STD distance distance from optimum (ERROR): {std_distance:.6f} / {std_distance:.6E}")
    
    
    # Plot convergence
    plt.figure(figsize=(10, 6))
    for i, conv in enumerate(all_convergences):
        plt.plot(conv, label=f'Run {i+1}')
    plt.title(f'Convergence Plot for Function {func_num}')
    plt.xlabel('Iteration')
    plt.ylabel('Best Fitness')
    #plt.legend()
    plt.yscale('log')  # Use log scale for y-axis to better visualize improvements
    plt.grid(True)
    plt.show()
    
    # Set the style
    plt.style.use('seaborn-whitegrid')

    # Create the figure and axis objects
    fig, ax = plt.subplots(figsize=(12, 7))

    # Convert all_convergences to a numpy array
    convergences_array = np.array(all_convergences)

    # Calculate median, 25th and 75th percentiles
    median_convergence = np.median(convergences_array, axis=0)
    mean_convergence = np.mean(convergences_array, axis=0)
    percentile_25 = np.percentile(convergences_array, 25, axis=0)
    percentile_75 = np.percentile(convergences_array, 75, axis=0)

    # Plot the median convergence
    ax.plot(median_convergence, color='black', linewidth=2, label='Median')
    ax.plot(mean_convergence, color='blue', linewidth=2, label='Mean')

    # Plot the shaded area for the interquartile range
    ax.fill_between(range(len(median_convergence)), 
                    percentile_25,
                    percentile_75,
                    color='blue', alpha=0.2, label='25th-75th percentile')

    # Optionally, plot the best and worst runs
    best_run = np.min(convergences_array, axis=0)
    worst_run = np.max(convergences_array, axis=0)
    ax.plot(best_run, color='green', linewidth=1, alpha=0.7, label='Best run')
    ax.plot(worst_run, color='red', linewidth=1, alpha=0.7, label='Worst run')

    # Customize the plot
    ax.set_title(f'Convergence Plot for Function {func_num}', fontsize=16, fontweight='bold')
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Best Fitness', fontsize=12)
    ax.set_yscale('log')
    ax.grid(True, which="both", ls="-", alpha=0.2)
    ax.tick_params(axis='both', which='major', labelsize=10)

    # Customize the legend
    ax.legend(fontsize=10, loc='upper right')

    # Improve the layout
    plt.tight_layout()

    # Show the plot
    plt.show()
# Out:
# Testing Function 21
#
# Function 21 optimization complete:
# Mean fitness: 2885.677177
# Median fitness: 2880.764479
# Best fitness: 2675.554098
# Worst fitness: 3150.054561
# Standard deviation: 165.056910
# Best distance from optimum (ERROR): 575.554098 / 5.755541E+02
# Worst distance from optimum (ERROR): 1050.054561 / 1.050055E+03
# Mean distance from optimum (ERROR): 785.677177 / 7.856772E+02
# Median distance from optimum (ERROR): 780.764479 / 7.807645E+02
# STD distance distance from optimum (ERROR): 165.056910 / 1.650569E+02
# Testing Function 22
#
# Function 22 optimization complete:
# Mean fitness: 12729.041846
# Median fitness: 13300.700955
# Best fitness: 5018.397236
# Worst fitness: 15824.463778
# Standard deviation: 2781.831671
# Best distance from optimum (ERROR): 2818.397236 / 2.818397E+03
# Worst distance from optimum (ERROR): 13624.463778 / 1.362446E+04
# Mean distance from optimum (ERROR): 10529.041846 / 1.052904E+04
# Median distance from optimum (ERROR): 11100.700955 / 1.110070E+04
# STD distance distance from optimum (ERROR): 2781.831671 / 2.781832E+03
# Testing Function 23
#
# Function 23 optimization complete:
# Mean fitness: 3928.241326
# Median fitness: 3876.368311
# Best fitness: 3566.016111
# Worst fitness: 4246.956672
# Standard deviation: 214.118270
# Best distance from optimum (ERROR): 1266.016111 / 1.266016E+03
# Worst distance from optimum (ERROR): 1946.956672 / 1.946957E+03
# Mean distance from optimum (ERROR): 1628.241326 / 1.628241E+03
# Median distance from optimum (ERROR): 1576.368311 / 1.576368E+03
# STD distance distance from optimum (ERROR): 214.118270 / 2.141183E+02
# Testing Function 24
#
# Function 24 optimization complete:
# Mean fitness: 3992.418142
# Median fitness: 4012.480956
# Best fitness: 3770.674598
# Worst fitness: 4335.325856
# Standard deviation: 162.432187
# Best distance from optimum (ERROR): 1370.674598 / 1.370675E+03
# Worst distance from optimum (ERROR): 1935.325856 / 1.935326E+03
# Mean distance from optimum (ERROR): 1592.418142 / 1.592418E+03
# Median distance from optimum (ERROR): 1612.480956 / 1.612481E+03
# STD distance distance from optimum (ERROR): 162.432187 / 1.624322E+02
# Testing Function 25
#
# Function 25 optimization complete:
# Mean fitness: 7881.384715
# Median fitness: 7427.600659
# Best fitness: 4973.726377
# Worst fitness: 13470.125724
# Standard deviation: 2497.841543
# Best distance from optimum (ERROR): 2473.726377 / 2.473726E+03
# Worst distance from optimum (ERROR): 10970.125724 / 1.097013E+04
# Mean distance from optimum (ERROR): 5381.384715 / 5.381385E+03
# Median distance from optimum (ERROR): 4927.600659 / 4.927601E+03
# STD distance distance from optimum (ERROR): 2497.841543 / 2.497842E+03
# Testing Function 26
#
# Function 26 optimization complete:
# Mean fitness: 16034.989710
# Median fitness: 16038.504361
# Best fitness: 10678.232500
# Worst fitness: 21999.549106
# Standard deviation: 3212.953247
# Best distance from optimum (ERROR): 8078.232500 / 8.078232E+03
# Worst distance from optimum (ERROR): 19399.549106 / 1.939955E+04
# Mean distance from optimum (ERROR): 13434.989710 / 1.343499E+04
# Median distance from optimum (ERROR): 13438.504361 / 1.343850E+04
# STD distance distance from optimum (ERROR): 3212.953247 / 3.212953E+03
# Testing Function 27
#
# Function 27 optimization complete:
# Mean fitness: 4549.279677
# Median fitness: 4580.959177
# Best fitness: 3987.713312
# Worst fitness: 5018.732928
# Standard deviation: 329.168275
# Best distance from optimum (ERROR): 1287.713312 / 1.287713E+03
# Worst distance from optimum (ERROR): 2318.732928 / 2.318733E+03
# Mean distance from optimum (ERROR): 1849.279677 / 1.849280E+03
# Median distance from optimum (ERROR): 1880.959177 / 1.880959E+03
# STD distance distance from optimum (ERROR): 329.168275 / 3.291683E+02
# Testing Function 28
#
# Function 28 optimization complete:
# Mean fitness: 10093.589508
# Median fitness: 9689.197355
# Best fitness: 7031.769630
# Worst fitness: 13357.077396
# Standard deviation: 2171.729933
# Best distance from optimum (ERROR): 4231.769630 / 4.231770E+03
# Worst distance from optimum (ERROR): 10557.077396 / 1.055708E+04
# Mean distance from optimum (ERROR): 7293.589508 / 7.293590E+03
# Median distance from optimum (ERROR): 6889.197355 / 6.889197E+03
# STD distance distance from optimum (ERROR): 2171.729933 / 2.171730E+03
# Testing Function 29
#
# Function 29 optimization complete:
# Mean fitness: nan
# Median fitness: nan
# Best fitness: nan
# Worst fitness: nan
# Standard deviation: nan
# Best distance from optimum (ERROR): nan / NAN
# Worst distance from optimum (ERROR): nan / NAN
# Mean distance from optimum (ERROR): nan / NAN
# Median distance from optimum (ERROR): nan / NAN
# STD distance distance from optimum (ERROR): nan / NAN
# Testing Function 30
#
# Function 30 optimization complete:
# Mean fitness: 6536892035.128834
# Median fitness: 826508998.605427
# Best fitness: 231654756.885069
# Worst fitness: 48157746188.641937
# Standard deviation: 13858308681.167896
# Best distance from optimum (ERROR): 231651756.885069 / 2.316518E+08
# Worst distance from optimum (ERROR): 48157743188.641937 / 4.815774E+10
# Mean distance from optimum (ERROR): 6536889035.128834 / 6.536889E+09
# Median distance from optimum (ERROR): 826505998.605427 / 8.265060E+08
# STD distance distance from optimum (ERROR): 13858308681.167896 / 1.385831E+10

# %%
def surface_plot_1(function, domain=(-100,100), points=30, dimension=2, ax=None):
    # create points^2 tuples of (x,y) and populate z
    xys = np.linspace(domain[0], domain[1], points)
    xys = np.transpose([np.tile(xys, len(xys)), np.repeat(xys, len(xys))])

    if dimension > 2:
        # concatenate remaining zeros
        tail = np.zeros((xys.shape[0], dimension - 2))
        x = np.concatenate([xys, tail], axis=1)
        zs = function(x)
    else:
        zs = function(xys)
    fig = plt.figure()
    ax = fig.gca(projection='3d')

    X = xys[:,0].reshape((points, points))
    Y = xys[:,1].reshape((points, points))
    Z = zs.reshape((points, points))
    surf = ax.plot_surface(X, Y, Z, cmap='plasma') #, edgecolor='none')
    cbar = fig.colorbar(surf, shrink=0.5, aspect=5, pad=0.15, label='')
    ax.set_title(function.__name__)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')

    # Set the axis color to match the background color
    ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))

    # Set the background color
    ax.set_facecolor((1.0, 1.0, 1.0, 0.0))
    plt.show()
    
    return fig

# %%
def contour_plot_1(function, domain=(-100,100), points=30, ax=None, dimension=2):
    # create points^2 tuples of (x,y) and populate z
    xys = np.linspace(domain[0], domain[1], points)
    xys = np.transpose([np.tile(xys, len(xys)), np.repeat(xys, len(xys))])

    if dimension > 2:
        # concatenate remaining zeros
        tail = np.zeros((xys.shape[0], dimension - 2))
        x = np.concatenate([xys, tail], axis=1)
        zs = function(x)
    else:
        zs = function(xys)

    fig = plt.figure()
    ax = fig.gca()

    X = xys[:,0].reshape((points, points))
    Y = xys[:,1].reshape((points, points))
    Z = zs.reshape((points, points))
    cont = ax.contourf(X, Y, Z, lw = 1, levels=20, cmap='plasma')
    ax.contour(X, Y, Z, colors="k", linestyles="solid")
    cbar = fig.colorbar(cont, shrink=0.5, aspect=5, pad=0.15, label='')
#     cbar = fig.colorbar(ax.collections[0], shrink=0.5, aspect=5, pad=0.15, label='')

    ax.set_title(function.__name__)
    ax.set_xlabel('x')
    ax.set_ylabel('y')

    # Set the background color
    ax.set_facecolor((1.0, 1.0, 1.0, 0.0))
    plt.show()
    
    return fig

# %%
def surface_plot_2(function, domain=(-100,100), points=30, dimension=2, ax=None):
    # create points^2 tuples of (x,y) and populate z
    xys = np.linspace(domain[0], domain[1], points)
    xys = np.transpose([np.tile(xys, len(xys)), np.repeat(xys, len(xys))])

    if dimension > 2:
        # concatenate remaining zeros
        tail = np.zeros((xys.shape[0], dimension - 2))
        x = np.concatenate([xys, tail], axis=1)
        zs = function(x)
    else:
        zs = function(xys)

    fig = plt.figure()
    ax = fig.gca(projection='3d')

    X = xys[:,0].reshape((points, points))
    Y = xys[:,1].reshape((points, points))
    Z = zs.reshape((points, points))

    # plot surface
    surf = ax.plot_surface(X, Y, Z, cmap='plasma') #, edgecolor='none')
    ax.contour(X, Y, Z, zdir='z', cmap="plasma", linestyles="solid", offset=40)
    ax.contour(X, Y, Z, zdir='z', colors="k", linestyles="solid")
    cbar = fig.colorbar(surf, shrink=0.5, aspect=5, pad=0.15, label='')
    ax.set_title(function.__name__)

    # plot contour
    ax.contour(X, Y, Z, levels=10, cmap='plasma')
    
    ax.set_title(function.__name__)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('y')

    # Set the background color
    ax.set_facecolor((1.0, 1.0, 1.0, 0.0))
    plt.show()
    
    return fig

# %%
Dim = 100
NP = 10
bound = 100

# %%
for f in functions.all_functions:
    surface_plot_2(f, points=120, dimension=Dim)
# Out:
# WARNING: f2 has been deprecated from the CEC 2017 benchmark suite

# %%
for f in functions.all_functions:
    contour_plot_1(f, points=120, dimension=Dim)
