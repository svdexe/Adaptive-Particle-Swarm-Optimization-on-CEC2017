# %%
import sys
sys.path.insert(1, '/kaggle/working/cec2017-py')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import cec2017.functions as functions

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
 
def standard_pso(objective_func, dim, num_particles, max_iter, bounds=(-100, 100)):
    # Initialize particles and velocities
    particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
    velocities = np.random.uniform(-1, 1, (num_particles, dim))
    
    # Initialize personal best and global best
    pbest = particles.copy()
    pbest_fitness = np.array([objective_func(p) for p in pbest])
    gbest = pbest[np.argmin(pbest_fitness)]
    gbest_fitness = np.min(pbest_fitness)
    
    # PSO parameters (constant for standard PSO)
    w = 0.7  # Inertia weight
    c1 = 2  # Cognitive parameter
    c2 = 2  # Social parameter
    
    convergence = []
    
    # Main PSO loop
    for iteration in range(max_iter):
        # Update velocities
        r1, r2 = np.random.rand(2)
        velocities = (w * velocities
                      + c1 * r1 * (pbest - particles)
                      + c2 * r2 * (gbest - particles))
        
        # Update particles
        particles += velocities
        
        # Apply bounds
        particles = np.clip(particles, bounds[0], bounds[1])
        
        # Evaluate fitness
        fitness = np.array([objective_func(p) for p in particles])
        
        # Update personal best
        improved = fitness < pbest_fitness
        pbest[improved] = particles[improved]
        pbest_fitness[improved] = fitness[improved]
        
        # Update global best
        if np.min(fitness) < gbest_fitness:
            gbest = particles[np.argmin(fitness)]
            gbest_fitness = np.min(fitness)
        
        convergence.append(gbest_fitness)
        
        # Print progress (commented out to match your code)
        if iteration % 250 == 0:
            pass
            #print(f"Iteration {iteration}: Best fitness = {gbest_fitness:.6f}")
    
    return gbest, gbest_fitness, w, c1, c2, convergence


# Set parameters
dim = 100
num_particles = 100
max_iter = 1000
bounds = (-100, 100)
num_iterations = 10

# List to store results for all functions
all_results = []

# Test all 30 functions
for func_num in range(1, 11):
    print(f"\nTesting Function {func_num}")
    
    # Get the CEC2017 function
    cec_function = getattr(functions, f'f{func_num}')
    
    # Create a wrapper function to handle the different input format
    def objective_func(x):
        return cec_function(x.reshape(1, -1))[0]
    
    # Run iterations
    results = []
    distances = []
    all_convergences = []
    for i in range(num_iterations):
        best_solution, best_fitness, final_w, final_c1, final_c2, convergence = standard_pso(objective_func, dim, num_particles, max_iter, bounds)
        distance = abs(best_fitness - func_num * 100)
        results.append(best_fitness)
        distances.append(distance)
        all_convergences.append(convergence)
        #print(f"Run {i+1}: Final fitness = {best_fitness:.6f}, Distance from optimum = {distance:.6f}, Final parameters: w = {final_w:.3f}, c1 = {final_c1:.3f}, c2 = {final_c2:.3f}")
    
    # Calculate statistics
    mean_fitness = np.mean(results)
    median_fitness = np.median(results)
    best_fitness = np.min(results)
    worst_fitness = np.max(results)
    std_fitness = np.std(results)
    best_distance = np.min(distances)
    worst_distance = np.max(distances)
    mean_distance = np.mean(distances)
    median_distance = np.median(distances)
    std_distance = np.std(distances)
    
    # Store results for this function
    all_results.append([best_fitness, worst_fitness, median_fitness, mean_fitness, std_fitness])
    
    print(f"\nFunction {func_num} optimization complete:")
    print(f"Mean fitness: {mean_fitness:.6f}")
    print(f"Median fitness: {median_fitness:.6f}")
    print(f"Best fitness: {best_fitness:.6f}")
    print(f"Worst fitness: {worst_fitness:.6f}")
    print(f"Standard deviation: {std_fitness:.6f}")
    print(f"Best distance from optimum (ERROR): {best_distance:.6f} / {best_distance:.6E}")
    print(f"Worst distance from optimum (ERROR): {worst_distance:.6f} / {worst_distance:.6E}")
    print(f"Mean distance from optimum (ERROR): {mean_distance:.6f} / {mean_distance:.6E}")
    print(f"Median distance from optimum (ERROR): {median_distance:.6f} / {median_distance:.6E}")
    print(f"STD distance distance from optimum (ERROR): {std_distance:.6f} / {std_distance:.6E}")
    
    
    # Plot convergence
    plt.figure(figsize=(10, 6))
    for i, conv in enumerate(all_convergences):
        plt.plot(conv, label=f'Run {i+1}')
    plt.title(f'Convergence Plot for Function {func_num}')
    plt.xlabel('Iteration')
    plt.ylabel('Best Fitness')
    #plt.legend()
    plt.yscale('log')  # Use log scale for y-axis to better visualize improvements
    plt.grid(True)
    plt.show()
    
    # Set the style
    plt.style.use('seaborn-whitegrid')

    # Create the figure and axis objects
    fig, ax = plt.subplots(figsize=(12, 7))

    # Convert all_convergences to a numpy array
    convergences_array = np.array(all_convergences)

    # Calculate median, 25th and 75th percentiles
    median_convergence = np.median(convergences_array, axis=0)
    mean_convergence = np.mean(convergences_array, axis=0)
    percentile_25 = np.percentile(convergences_array, 25, axis=0)
    percentile_75 = np.percentile(convergences_array, 75, axis=0)

    # Plot the median convergence
    ax.plot(median_convergence, color='black', linewidth=2, label='Median')
    ax.plot(mean_convergence, color='blue', linewidth=2, label='Mean')

    # Plot the shaded area for the interquartile range
    ax.fill_between(range(len(median_convergence)), 
                    percentile_25,
                    percentile_75,
                    color='blue', alpha=0.2, label='25th-75th percentile')

    # Optionally, plot the best and worst runs
    best_run = np.min(convergences_array, axis=0)
    worst_run = np.max(convergences_array, axis=0)
    ax.plot(best_run, color='green', linewidth=1, alpha=0.7, label='Best run')
    ax.plot(worst_run, color='red', linewidth=1, alpha=0.7, label='Worst run')

    # Customize the plot
    ax.set_title(f'Convergence Plot for Function {func_num}', fontsize=16, fontweight='bold')
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Best Fitness', fontsize=12)
    ax.set_yscale('log')
    ax.grid(True, which="both", ls="-", alpha=0.2)
    ax.tick_params(axis='both', which='major', labelsize=10)

    # Customize the legend
    ax.legend(fontsize=10, loc='upper right')

    # Improve the layout
    plt.tight_layout()

    # Show the plot
    plt.show()
# Out:
# Testing Function 1
#
# Function 1 optimization complete:
# Mean fitness: 1986870168627.729004
# Median fitness: 1896481797938.793213
# Best fitness: 1227062861979.822754
# Worst fitness: 3065075018380.063477
# Standard deviation: 599908237646.565308
# Best distance from optimum (ERROR): 1227062861879.822754 / 1.227063E+12
# Worst distance from optimum (ERROR): 3065075018280.063477 / 3.065075E+12
# Mean distance from optimum (ERROR): 1986870168527.729004 / 1.986870E+12
# Median distance from optimum (ERROR): 1896481797838.793213 / 1.896482E+12
# STD distance distance from optimum (ERROR): 599908237646.565308 / 5.999082E+11
# Testing Function 2
# WARNING: f2 has been deprecated from the CEC 2017 benchmark suite
#
# Function 2 optimization complete:
# Mean fitness: 1022462229269904134836294619824568641847376145178103333662950886504694621002649417933014718391306822503897600786361292642395212622137788284619451461418800095061606400.000000
# Median fitness: 126602758786103980313351786852474990050528016067514069956743753604914336544752684338557425024838258505545687954129863297428444126293870781858014298112.000000
# Best fitness: 95037673774450066915116897843523577812744214614038938232658078147361592087997229335721023958897613887745180471266970656568411426914304.000000
# Worst fitness: 10224622285556254264247364531094785497578981204108751927368042221470403714696754929406620549891601755056836368244434714269622356713869128551575099681953100782500839424.000000
# Standard deviation: inf
# Best distance from optimum (ERROR): 95037673774450066915116897843523577812744214614038938232658078147361592087997229335721023958897613887745180471266970656568411426914304.000000 / 9.503767E+133
# Worst distance from optimum (ERROR): 10224622285556254264247364531094785497578981204108751927368042221470403714696754929406620549891601755056836368244434714269622356713869128551575099681953100782500839424.000000 / 1.022462E+166
# Mean distance from optimum (ERROR): 1022462229269904134836294619824568641847376145178103333662950886504694621002649417933014718391306822503897600786361292642395212622137788284619451461418800095061606400.000000 / 1.022462E+165
# Median distance from optimum (ERROR): 126602758786103980313351786852474990050528016067514069956743753604914336544752684338557425024838258505545687954129863297428444126293870781858014298112.000000 / 1.266028E+149
# STD distance distance from optimum (ERROR): inf / INF
# Testing Function 3
#
# Function 3 optimization complete:
# Mean fitness: 1070928.654140
# Median fitness: 926938.013295
# Best fitness: 370942.228523
# Worst fitness: 2232725.053916
# Standard deviation: 645619.138774
# Best distance from optimum (ERROR): 370642.228523 / 3.706422E+05
# Worst distance from optimum (ERROR): 2232425.053916 / 2.232425E+06
# Mean distance from optimum (ERROR): 1070628.654140 / 1.070629E+06
# Median distance from optimum (ERROR): 926638.013295 / 9.266380E+05
# STD distance distance from optimum (ERROR): 645619.138774 / 6.456191E+05
# Testing Function 4
#
# Function 4 optimization complete:
# Mean fitness: 42606.148790
# Median fitness: 37747.014151
# Best fitness: 25378.443011
# Worst fitness: 105945.301752
# Standard deviation: 22411.300523
# Best distance from optimum (ERROR): 24978.443011 / 2.497844E+04
# Worst distance from optimum (ERROR): 105545.301752 / 1.055453E+05
# Mean distance from optimum (ERROR): 42206.148790 / 4.220615E+04
# Median distance from optimum (ERROR): 37347.014151 / 3.734701E+04
# STD distance distance from optimum (ERROR): 22411.300523 / 2.241130E+04
# Testing Function 5
#
# Function 5 optimization complete:
# Mean fitness: 2034.128860
# Median fitness: 2026.608050
# Best fitness: 1709.691946
# Worst fitness: 2530.976557
# Standard deviation: 267.011601
# Best distance from optimum (ERROR): 1209.691946 / 1.209692E+03
# Worst distance from optimum (ERROR): 2030.976557 / 2.030977E+03
# Mean distance from optimum (ERROR): 1534.128860 / 1.534129E+03
# Median distance from optimum (ERROR): 1526.608050 / 1.526608E+03
# STD distance distance from optimum (ERROR): 267.011601 / 2.670116E+02
# Testing Function 6
#
# Function 6 optimization complete:
# Mean fitness: 716.814704
# Median fitness: 714.985751
# Best fitness: 689.430021
# Worst fitness: 765.876863
# Standard deviation: 20.492724
# Best distance from optimum (ERROR): 89.430021 / 8.943002E+01
# Worst distance from optimum (ERROR): 165.876863 / 1.658769E+02
# Mean distance from optimum (ERROR): 116.814704 / 1.168147E+02
# Median distance from optimum (ERROR): 114.985751 / 1.149858E+02
# STD distance distance from optimum (ERROR): 20.492724 / 2.049272E+01
# Testing Function 7
#
# Function 7 optimization complete:
# Mean fitness: 4240.883996
# Median fitness: 3970.019799
# Best fitness: 3321.494276
# Worst fitness: 6428.662799
# Standard deviation: 856.957889
# Best distance from optimum (ERROR): 2621.494276 / 2.621494E+03
# Worst distance from optimum (ERROR): 5728.662799 / 5.728663E+03
# Mean distance from optimum (ERROR): 3540.883996 / 3.540884E+03
# Median distance from optimum (ERROR): 3270.019799 / 3.270020E+03
# STD distance distance from optimum (ERROR): 856.957889 / 8.569579E+02
# Testing Function 8
#
# Function 8 optimization complete:
# Mean fitness: 2394.637684
# Median fitness: 2338.520537
# Best fitness: 2130.124079
# Worst fitness: 3218.109662
# Standard deviation: 300.760129
# Best distance from optimum (ERROR): 1330.124079 / 1.330124E+03
# Worst distance from optimum (ERROR): 2418.109662 / 2.418110E+03
# Mean distance from optimum (ERROR): 1594.637684 / 1.594638E+03
# Median distance from optimum (ERROR): 1538.520537 / 1.538521E+03
# STD distance distance from optimum (ERROR): 300.760129 / 3.007601E+02
# Testing Function 9
#
# Function 9 optimization complete:
# Mean fitness: 71585.948546
# Median fitness: 69481.370957
# Best fitness: 39151.432324
# Worst fitness: 107736.930149
# Standard deviation: 18124.005189
# Best distance from optimum (ERROR): 38251.432324 / 3.825143E+04
# Worst distance from optimum (ERROR): 106836.930149 / 1.068369E+05
# Mean distance from optimum (ERROR): 70685.948546 / 7.068595E+04
# Median distance from optimum (ERROR): 68581.370957 / 6.858137E+04
# STD distance distance from optimum (ERROR): 18124.005189 / 1.812401E+04
# Testing Function 10
#
# Function 10 optimization complete:
# Mean fitness: 27432.373531
# Median fitness: 26848.637555
# Best fitness: 24805.787887
# Worst fitness: 32671.372269
# Standard deviation: 2206.559003
# Best distance from optimum (ERROR): 23805.787887 / 2.380579E+04
# Worst distance from optimum (ERROR): 31671.372269 / 3.167137E+04
# Mean distance from optimum (ERROR): 26432.373531 / 2.643237E+04
# Median distance from optimum (ERROR): 25848.637555 / 2.584864E+04
# STD distance distance from optimum (ERROR): 2206.559003 / 2.206559E+03

# %%
def surface_plot_1(function, domain=(-100,100), points=30, dimension=2, ax=None):
    # create points^2 tuples of (x,y) and populate z
    xys = np.linspace(domain[0], domain[1], points)
    xys = np.transpose([np.tile(xys, len(xys)), np.repeat(xys, len(xys))])

    if dimension > 2:
        # concatenate remaining zeros
        tail = np.zeros((xys.shape[0], dimension - 2))
        x = np.concatenate([xys, tail], axis=1)
        zs = function(x)
    else:
        zs = function(xys)
    fig = plt.figure()
    ax = fig.gca(projection='3d')

    X = xys[:,0].reshape((points, points))
    Y = xys[:,1].reshape((points, points))
    Z = zs.reshape((points, points))
    surf = ax.plot_surface(X, Y, Z, cmap='plasma') #, edgecolor='none')
    cbar = fig.colorbar(surf, shrink=0.5, aspect=5, pad=0.15, label='')
    ax.set_title(function.__name__)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')

    # Set the axis color to match the background color
    ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))

    # Set the background color
    ax.set_facecolor((1.0, 1.0, 1.0, 0.0))
    plt.show()
    
    return fig

# %%
def contour_plot_1(function, domain=(-100,100), points=30, ax=None, dimension=2):
    # create points^2 tuples of (x,y) and populate z
    xys = np.linspace(domain[0], domain[1], points)
    xys = np.transpose([np.tile(xys, len(xys)), np.repeat(xys, len(xys))])

    if dimension > 2:
        # concatenate remaining zeros
        tail = np.zeros((xys.shape[0], dimension - 2))
        x = np.concatenate([xys, tail], axis=1)
        zs = function(x)
    else:
        zs = function(xys)

    fig = plt.figure()
    ax = fig.gca()

    X = xys[:,0].reshape((points, points))
    Y = xys[:,1].reshape((points, points))
    Z = zs.reshape((points, points))
    cont = ax.contourf(X, Y, Z, lw = 1, levels=20, cmap='plasma')
    ax.contour(X, Y, Z, colors="k", linestyles="solid")
    cbar = fig.colorbar(cont, shrink=0.5, aspect=5, pad=0.15, label='')
#     cbar = fig.colorbar(ax.collections[0], shrink=0.5, aspect=5, pad=0.15, label='')

    ax.set_title(function.__name__)
    ax.set_xlabel('x')
    ax.set_ylabel('y')

    # Set the background color
    ax.set_facecolor((1.0, 1.0, 1.0, 0.0))
    plt.show()
    
    return fig

# %%
def surface_plot_2(function, domain=(-100,100), points=30, dimension=2, ax=None):
    # create points^2 tuples of (x,y) and populate z
    xys = np.linspace(domain[0], domain[1], points)
    xys = np.transpose([np.tile(xys, len(xys)), np.repeat(xys, len(xys))])

    if dimension > 2:
        # concatenate remaining zeros
        tail = np.zeros((xys.shape[0], dimension - 2))
        x = np.concatenate([xys, tail], axis=1)
        zs = function(x)
    else:
        zs = function(xys)

    fig = plt.figure()
    ax = fig.gca(projection='3d')

    X = xys[:,0].reshape((points, points))
    Y = xys[:,1].reshape((points, points))
    Z = zs.reshape((points, points))

    # plot surface
    surf = ax.plot_surface(X, Y, Z, cmap='plasma') #, edgecolor='none')
    ax.contour(X, Y, Z, zdir='z', cmap="plasma", linestyles="solid", offset=40)
    ax.contour(X, Y, Z, zdir='z', colors="k", linestyles="solid")
    cbar = fig.colorbar(surf, shrink=0.5, aspect=5, pad=0.15, label='')
    ax.set_title(function.__name__)

    # plot contour
    ax.contour(X, Y, Z, levels=10, cmap='plasma')
    
    ax.set_title(function.__name__)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('y')

    # Set the background color
    ax.set_facecolor((1.0, 1.0, 1.0, 0.0))
    plt.show()
    
    return fig

# %%
Dim = 100
NP = 10
bound = 100

# %%
for f in functions.all_functions:
    surface_plot_2(f, points=120, dimension=Dim)

# %%
for f in functions.all_functions:
    contour_plot_1(f, points=120, dimension=Dim)
