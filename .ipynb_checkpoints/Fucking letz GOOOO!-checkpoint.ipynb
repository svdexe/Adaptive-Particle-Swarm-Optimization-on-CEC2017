# %%
import numpy as np

class CEC17Function:
    def __init__(self, dim, function_number):
        self.dim = dim
        self.function_number = function_number
        self.shift_vector = self.generate_shift_vector()
        self.rotation_matrix = self.generate_rotation_matrix()
        self.optimum = 100 * function_number

    def generate_shift_vector(self):
        return np.random.uniform(-80, 80, self.dim)

    def generate_rotation_matrix(self):
        A = np.random.randn(self.dim, self.dim)
        Q, _ = np.linalg.qr(A)
        return Q

    def transform(self, x):
        return np.dot(x - self.shift_vector, self.rotation_matrix)

    def __call__(self, x):
        z = self.transform(x)
        if self.function_number == 1:
            return self.bent_cigar(z) + self.optimum
        elif self.function_number == 2:
            return self.zakharov(z) + self.optimum
        elif self.function_number == 3:
            return self.rosenbrock(z) + self.optimum
        elif self.function_number == 4:
            return self.rastrigin(z) + self.optimum
        elif self.function_number == 5:
            return self.schaffer(z) + self.optimum
        else:
            raise ValueError("Function number not implemented")

    def bent_cigar(self, z):
        return z[0]**2 + 1e6 * np.sum(z[1:]**2)

    def zakharov(self, z):
        sum1 = np.sum(z**2)
        sum2 = np.sum(0.5 * np.arange(1, self.dim+1) * z)
        return sum1 + sum2**2 + sum2**4

    def rosenbrock(self, z):
        return np.sum(100 * (z[1:] - z[:-1]**2)**2 + (z[:-1] - 1)**2)

    def rastrigin(self, z):
        return np.sum(z**2 - 10 * np.cos(2 * np.pi * z) + 10)

    def schaffer(self, z):
        z_square = z**2
        return 0.5 + (np.sin(np.sqrt(z_square + z_square[1:]))**2 - 0.5) / (1 + 0.001 * (z_square + z_square[1:]))**2
    
def adaptive_pso(objective_func, dim, num_particles, max_iter, bounds=(-100, 100)):
    # Initialize particles and velocities
    particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
    velocities = np.random.uniform(-1, 1, (num_particles, dim))
    
    # Initialize personal best and global best
    pbest = particles.copy()
    pbest_fitness = np.array([objective_func(p) for p in pbest])
    gbest = pbest[np.argmin(pbest_fitness)]
    gbest_fitness = np.min(pbest_fitness)
    
    # PSO parameters
    w_max, w_min = 0.9, 0.4  # Inertia weight bounds
    c1_max, c1_min = 2.5, 0.5  # Cognitive parameter bounds
    c2_max, c2_min = 2.5, 0.5  # Social parameter bounds
    
    # Adaptive parameter variables
    w = w_max
    c1 = c1_max
    c2 = c2_min
    
    # Variables for adaptation
    prev_best_fitness = gbest_fitness
    stagnation_counter = 0
    
    # Main PSO loop
    for iteration in range(max_iter):
        # Calculate progress
        progress = iteration / max_iter
        
        # Adapt parameters
        w = w_max - (w_max - w_min) * progress
        c1 = c1_max - (c1_max - c1_min) * progress
        c2 = c2_min + (c2_max - c2_min) * progress
        
        # Update velocities
        r1, r2 = np.random.rand(2)
        velocities = (w * velocities
                      + c1 * r1 * (pbest - particles)
                      + c2 * r2 * (gbest - particles))
        
        # Update particles
        particles += velocities
        
        # Apply bounds
        particles = np.clip(particles, bounds[0], bounds[1])
        
        # Evaluate fitness
        fitness = np.array([objective_func(p) for p in particles])
        
        # Update personal best
        improved = fitness < pbest_fitness
        pbest[improved] = particles[improved]
        pbest_fitness[improved] = fitness[improved]
        
        # Update global best
        if np.min(fitness) < gbest_fitness:
            gbest = particles[np.argmin(fitness)]
            gbest_fitness = np.min(fitness)
            stagnation_counter = 0
        else:
            stagnation_counter += 1
        
        # Adaptation based on improvement
        if gbest_fitness < prev_best_fitness:
            # If improving, increase exploration
            w = min(w_max, w * 1.05)
            c1 = min(c1_max, c1 * 1.05)
            c2 = max(c2_min, c2 * 0.95)
        else:
            # If stagnating, increase exploitation
            w = max(w_min, w * 0.95)
            c1 = max(c1_min, c1 * 0.95)
            c2 = min(c2_max, c2 * 1.05)
        
        # Store current best fitness for next iteration's comparison
        prev_best_fitness = gbest_fitness
        
        # Print progress
        if iteration % 100 == 0:
            print(f"Iteration {iteration}: Best fitness = {gbest_fitness:.6f}, w = {w:.4f}, c1 = {c1:.4f}, c2 = {c2:.4f}")
        
        # Optional: Reset if stagnation occurs for too long
        if stagnation_counter > 50:
            particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
            velocities = np.random.uniform(-1, 1, (num_particles, dim))
            stagnation_counter = 0
    
    return gbest, gbest_fitness

# Set parameters
dim = 10
num_particles = 100
max_iter = 1000
bounds = (-100, 100)

# Test all 5 functions
for func_num in range(1, 5):
    print(f"\nTesting Function {func_num}")
    cec_function = CEC17Function(dim, func_num)
    
    best_solution, best_fitness = adaptive_pso(cec_function, dim, num_particles, max_iter, bounds)

    print(f"Function {func_num} optimization complete:")
    print(f"Best fitness: {best_fitness:.6f}")
    print(f"Distance from optimum: {abs(best_fitness - cec_function.optimum):.6f}")
# Out:
# Testing Function 1
# Iteration 0: Best fitness = 13357575177.126886, w = 0.9000, c1 = 2.5000, c2 = 0.5000
# Iteration 100: Best fitness = 37242281.819289, w = 0.8075, c1 = 2.1850, c2 = 0.7350
# Iteration 200: Best fitness = 22108862.114405, w = 0.7600, c1 = 1.9950, c2 = 0.9450
# Iteration 300: Best fitness = 22108862.114405, w = 0.7125, c1 = 1.8050, c2 = 1.1550
# Iteration 400: Best fitness = 22108862.114405, w = 0.6650, c1 = 1.6150, c2 = 1.3650
# Iteration 500: Best fitness = 37069.651465, w = 0.6825, c1 = 1.5750, c2 = 1.4250
# Iteration 600: Best fitness = 502.272658, w = 0.6300, c1 = 1.3650, c2 = 1.6150
# Iteration 700: Best fitness = 500.495881, w = 0.5775, c1 = 1.1550, c2 = 1.8050
# Iteration 800: Best fitness = 500.495881, w = 0.4750, c1 = 0.8550, c2 = 2.2050
# Iteration 900: Best fitness = 463.233363, w = 0.4725, c1 = 0.7350, c2 = 2.1850
# Function 1 optimization complete:
# Best fitness: 463.230594
# Distance from optimum: 363.230594
#
# Testing Function 2
# Iteration 0: Best fitness = 18184.510158, w = 0.8550, c1 = 2.3750, c2 = 0.5250
# Iteration 100: Best fitness = 3950.424122, w = 0.8075, c1 = 2.1850, c2 = 0.7350
# Iteration 200: Best fitness = 2947.191965, w = 0.7600, c1 = 1.9950, c2 = 0.9450
# Iteration 300: Best fitness = 210.891608, w = 0.7875, c1 = 1.9950, c2 = 1.0450
# Iteration 400: Best fitness = 200.873991, w = 0.7350, c1 = 1.7850, c2 = 1.2350
# Iteration 500: Best fitness = 200.847684, w = 0.6825, c1 = 1.5750, c2 = 1.4250
# Iteration 600: Best fitness = 200.847684, w = 0.6300, c1 = 1.3650, c2 = 1.6150
# Iteration 700: Best fitness = 200.499826, w = 0.5225, c1 = 1.0450, c2 = 1.9950
# Iteration 800: Best fitness = 200.059247, w = 0.5250, c1 = 0.9450, c2 = 1.9950
# Iteration 900: Best fitness = 200.059247, w = 0.4275, c1 = 0.6650, c2 = 2.4150
# Function 2 optimization complete:
# Best fitness: 200.051264
# Distance from optimum: 0.051264
#
# Testing Function 3
# Iteration 0: Best fitness = 1430196720.904397, w = 0.9000, c1 = 2.5000, c2 = 0.5000
# Iteration 100: Best fitness = 158095.243954, w = 0.8075, c1 = 2.1850, c2 = 0.7350
# Iteration 200: Best fitness = 1240.991357, w = 0.7600, c1 = 1.9950, c2 = 0.9450
# Iteration 300: Best fitness = 1083.769581, w = 0.7875, c1 = 1.9950, c2 = 1.0450
# Iteration 400: Best fitness = 1077.416674, w = 0.7350, c1 = 1.7850, c2 = 1.2350
# Iteration 500: Best fitness = 1077.416587, w = 0.6825, c1 = 1.5750, c2 = 1.4250
# Iteration 600: Best fitness = 1077.416587, w = 0.5700, c1 = 1.2350, c2 = 1.7850
# Iteration 700: Best fitness = 1076.995614, w = 0.5225, c1 = 1.0450, c2 = 1.9950
# Iteration 800: Best fitness = 1076.986792, w = 0.4750, c1 = 0.8550, c2 = 2.2050
# Iteration 900: Best fitness = 1073.206262, w = 0.4275, c1 = 0.6650, c2 = 2.4150
# Function 3 optimization complete:
# Best fitness: 1072.932678
# Distance from optimum: 772.932678
#
# Testing Function 4
# Iteration 0: Best fitness = 8807.514318, w = 0.9000, c1 = 2.5000, c2 = 0.5000
# Iteration 100: Best fitness = 528.454887, w = 0.8075, c1 = 2.1850, c2 = 0.7350
# Iteration 200: Best fitness = 464.881828, w = 0.7600, c1 = 1.9950, c2 = 0.9450
# Iteration 300: Best fitness = 453.717606, w = 0.7125, c1 = 1.8050, c2 = 1.1550
# Iteration 400: Best fitness = 443.579768, w = 0.6650, c1 = 1.6150, c2 = 1.3650
# Iteration 500: Best fitness = 442.612938, w = 0.6175, c1 = 1.4250, c2 = 1.5750
# Iteration 600: Best fitness = 442.612938, w = 0.5700, c1 = 1.2350, c2 = 1.7850
# Iteration 700: Best fitness = 442.612938, w = 0.5225, c1 = 1.0450, c2 = 1.9950
# Iteration 800: Best fitness = 442.612938, w = 0.4750, c1 = 0.8550, c2 = 2.2050
# Iteration 900: Best fitness = 442.612938, w = 0.4275, c1 = 0.6650, c2 = 2.4150
# Function 4 optimization complete:
# Best fitness: 442.612938
# Distance from optimum: 42.612938

# %%
def adaptive_pso(objective_func, dim, num_particles, max_iter, bounds=(-100, 100)):
    # Initialize particles and velocities
    particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
    velocities = np.random.uniform(-1, 1, (num_particles, dim))
    
    # Initialize personal best and global best
    pbest = particles.copy()
    pbest_fitness = np.array([objective_func(p) for p in pbest])
    gbest = pbest[np.argmin(pbest_fitness)]
    gbest_fitness = np.min(pbest_fitness)
    
    # PSO parameters
    w_max, w_min = 0.9, 0.4  # Inertia weight bounds
    c1_max, c1_min = 2.5, 0.5  # Cognitive parameter bounds
    c2_max, c2_min = 2.5, 0.5  # Social parameter bounds
    
    # Adaptive parameter variables
    w = w_max
    c1 = c1_max
    c2 = c2_min
    
    # Variables for adaptation
    prev_best_fitness = gbest_fitness
    stagnation_counter = 0
    
    # Main PSO loop
    for iteration in range(max_iter):
        # Calculate progress
        progress = iteration / max_iter
        
        # Adapt parameters
        w = w_max - (w_max - w_min) * progress
        c1 = c1_max - (c1_max - c1_min) * progress
        c2 = c2_min + (c2_max - c2_min) * progress
        
        # Update velocities
        r1, r2 = np.random.rand(2)
        velocities = (w * velocities
                      + c1 * r1 * (pbest - particles)
                      + c2 * r2 * (gbest - particles))
        
        # Update particles
        particles += velocities
        
        # Apply bounds
        particles = np.clip(particles, bounds[0], bounds[1])
        
        # Evaluate fitness
        fitness = np.array([objective_func(p) for p in particles])
        
        # Update personal best
        improved = fitness < pbest_fitness
        pbest[improved] = particles[improved]
        pbest_fitness[improved] = fitness[improved]
        
        # Update global best
        if np.min(fitness) < gbest_fitness:
            gbest = particles[np.argmin(fitness)]
            gbest_fitness = np.min(fitness)
            stagnation_counter = 0
        else:
            stagnation_counter += 1
        
        # Adaptation based on improvement
        if gbest_fitness < prev_best_fitness:
            # If improving, increase exploration
            w = min(w_max, w * 1.05)
            c1 = min(c1_max, c1 * 1.05)
            c2 = max(c2_min, c2 * 0.95)
        else:
            # If stagnating, increase exploitation
            w = max(w_min, w * 0.95)
            c1 = max(c1_min, c1 * 0.95)
            c2 = min(c2_max, c2 * 1.05)
        
        # Store current best fitness for next iteration's comparison
        prev_best_fitness = gbest_fitness
        
        # Print progress
        if iteration % 100 == 0:
            print(f"Iteration {iteration}: Best fitness = {gbest_fitness:.6f}, w = {w:.4f}, c1 = {c1:.4f}, c2 = {c2:.4f}")
        
        # Optional: Reset if stagnation occurs for too long
        if stagnation_counter > 50:
            particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
            velocities = np.random.uniform(-1, 1, (num_particles, dim))
            stagnation_counter = 0
    
    return gbest, gbest_fitness

# %%
import sys
sys.path.insert(1, '/kaggle/working/cec2017-py')

import numpy as np
import cec2017.functions as functions

    
def adaptive_pso(objective_func, dim, num_particles, max_iter, bounds=(-100, 100)):
    # Initialize particles and velocities
    particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
    velocities = np.random.uniform(-1, 1, (num_particles, dim))
    
    # Initialize personal best and global best
    pbest = particles.copy()
    pbest_fitness = np.array([objective_func(p) for p in pbest])
    gbest = pbest[np.argmin(pbest_fitness)]
    gbest_fitness = np.min(pbest_fitness)
    
    # PSO parameters
    w_max, w_min = 0.9, 0.2  # Inertia weight bounds
    c1_max, c1_min = 2.5, 0.5  # Cognitive parameter bounds
    c2_max, c2_min = 2.5, 0.  # Social parameter bounds
    
    # Adaptive parameter variables
    w = w_max
    c1 = c1_max
    c2 = c2_min
    
    # Variables for adaptation
    prev_best_fitness = gbest_fitness
    stagnation_counter = 0
    
    # Main PSO loop
    for iteration in range(max_iter):
        # Calculate progress
        progress = iteration / max_iter
        
        # Adapt parameters
        w = w_max - (w_max - w_min) * progress
        c1 = c1_max - (c1_max - c1_min) * progress
        c2 = c2_min + (c2_max - c2_min) * progress
        
        # Update velocities
        r1, r2 = np.random.rand(2)
        velocities = (w * velocities
                      + c1 * r1 * (pbest - particles)
                      + c2 * r2 * (gbest - particles))
        
        # Update particles
        particles += velocities
        
        # Apply bounds
        particles = np.clip(particles, bounds[0], bounds[1])
        
        # Evaluate fitness
        fitness = np.array([objective_func(p) for p in particles])
        
        # Update personal best
        improved = fitness < pbest_fitness
        pbest[improved] = particles[improved]
        pbest_fitness[improved] = fitness[improved]
        
        # Update global best
        if np.min(fitness) < gbest_fitness:
            gbest = particles[np.argmin(fitness)]
            gbest_fitness = np.min(fitness)
            stagnation_counter = 0
        else:
            stagnation_counter += 1
        
        # Adaptation based on improvement
        if gbest_fitness < prev_best_fitness:
            # If improving, increase exploration
            w = min(w_max, w * 1.05)
            c1 = min(c1_max, c1 * 1.05)
            c2 = max(c2_min, c2 * 0.95)
        else:
            # If stagnating, increase exploitation
            w = max(w_min, w * 0.95)
            c1 = max(c1_min, c1 * 0.95)
            c2 = min(c2_max, c2 * 1.05)
        
        # Store current best fitness for next iteration's comparison
        prev_best_fitness = gbest_fitness
        
        # Print progress
        if iteration % 100 == 0:
            print(f"Iteration {iteration}: Best fitness = {gbest_fitness:.6f}, w = {w:.4f}, c1 = {c1:.4f}, c2 = {c2:.4f}")
        
        # Optional: Reset if stagnation occurs for too long
        if stagnation_counter > 50:
            particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
            velocities = np.random.uniform(-1, 1, (num_particles, dim))
            stagnation_counter = 0
    
    return gbest, gbest_fitness

# Set parameters
dim = 10
num_particles = 100
max_iter = 1000
bounds = (-100, 100)

# Test all 30 functions
for func_num in range(1, 31):
    print(f"\nTesting Function {func_num}")
    
    # Get the CEC2017 function
    cec_function = getattr(functions, f'f{func_num}')
    
    # Create a wrapper function to handle the different input format
    def objective_func(x):
        return cec_function(x.reshape(1, -1))[0]
    
    best_solution, best_fitness = adaptive_pso(objective_func, dim, num_particles, max_iter, bounds)

    print(f"Function {func_num} optimization complete:")
    print(f"Best fitness: {best_fitness:.6f}")
    print(f"Distance from optimum: {abs(best_fitness - func_num * 100):.6f}")
# Out:
# Testing Function 1
# Iteration 0: Best fitness = 241016006226.348450, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 2746056.558451, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 185461.903924, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 185370.590362, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 185370.590161, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 1789.789250, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 1447.492121, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 1144.344882, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 1012.817734, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 1012.817734, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 1 optimization complete:
# Best fitness: 1012.817734
# Distance from optimum: 912.817734
#
# Testing Function 2
# Iteration 0: Best fitness = 146930927384932.156250, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 18525200.227742, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 1116408.880602, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 1109080.985417, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 1109080.969302, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 1109080.969302, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 743737.077314, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 737272.420298, w = 0.4305, c1 = 1.1550, c2 = 1.6625
# Iteration 800: Best fitness = 355967.535884, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 355967.161755, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 2 optimization complete:
# Best fitness: 67664.063295
# Distance from optimum: 67464.063295
#
# Testing Function 3
# Iteration 0: Best fitness = 51642.196681, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 829.387209, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 388.805700, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 342.333634, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 342.333156, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 342.333156, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 329.236867, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 328.719704, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 302.527445, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 302.527399, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 3 optimization complete:
# Best fitness: 300.081908
# Distance from optimum: 0.081908
#
# Testing Function 4
# Iteration 0: Best fitness = 2196.169865, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 403.409616, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 402.838180, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 402.837201, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 402.837201, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 402.708297, w = 0.5775, c1 = 1.5750, c2 = 1.1875
# Iteration 600: Best fitness = 402.708297, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 402.573076, w = 0.4305, c1 = 1.1550, c2 = 1.6625
# Iteration 800: Best fitness = 402.563279, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 402.548814, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 4 optimization complete:
# Best fitness: 402.548814
# Distance from optimum: 2.548814
#
# Testing Function 5
# Iteration 0: Best fitness = 598.709819, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 547.417277, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 547.253474, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 511.617082, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 510.988614, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 510.988614, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 510.948633, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 510.948633, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 510.944601, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 510.944581, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 5 optimization complete:
# Best fitness: 510.944581
# Distance from optimum: 10.944581
#
# Testing Function 6
# Iteration 0: Best fitness = 689.926562, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 618.706202, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 609.152870, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 607.582207, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = 607.467446, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 607.467426, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 607.467426, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 607.427818, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 607.427818, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 607.427818, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 6 optimization complete:
# Best fitness: 607.293661
# Distance from optimum: 7.293661
#
# Testing Function 7
# Iteration 0: Best fitness = 1337.460763, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 757.304382, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 738.257556, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 732.404178, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 732.403549, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 732.403549, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 732.196138, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 732.196138, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 732.196127, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 732.196123, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 7 optimization complete:
# Best fitness: 732.196122
# Distance from optimum: 32.196122
#
# Testing Function 8
# Iteration 0: Best fitness = 915.853082, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 828.568902, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 811.694411, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 809.960992, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 809.955887, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 809.955886, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 809.949815, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 809.949807, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 809.949633, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 809.949620, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 8 optimization complete:
# Best fitness: 809.949620
# Distance from optimum: 9.949620
#
# Testing Function 9
# Iteration 0: Best fitness = 4633.656757, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 1082.609287, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 1012.863908, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 953.449485, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 953.420222, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 953.420222, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 953.283118, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 953.269553, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 953.229177, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 953.186604, w = 0.2835, c1 = 0.7350, c2 = 2.1375
# Function 9 optimization complete:
# Best fitness: 953.173484
# Distance from optimum: 53.173484
#
# Testing Function 10
# Iteration 0: Best fitness = 3101.382202, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 2562.679954, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 2300.807448, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 2129.393013, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 2114.769672, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 2114.689852, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 2114.682831, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 2114.682120, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 2114.671594, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 2114.671585, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 10 optimization complete:
# Best fitness: 2114.670585
# Distance from optimum: 1114.670585
#
# Testing Function 11
# Iteration 0: Best fitness = 4814.667546, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 1222.057860, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 1220.635621, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 1220.634447, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 1220.634447, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 1220.634447, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 1220.632281, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 1220.631907, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 1220.631900, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 1220.631807, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 11 optimization complete:
# Best fitness: 1220.630809
# Distance from optimum: 120.630809
#
# Testing Function 12
# Iteration 0: Best fitness = 5606490070.311714, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 1769232.037645, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 884283.824013, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 772484.984431, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 772484.907523, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 535746.072438, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 438102.644700, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 438102.644536, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 427893.443665, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 417580.229383, w = 0.2835, c1 = 0.7350, c2 = 2.1375
# Function 12 optimization complete:
# Best fitness: 417573.378415
# Distance from optimum: 416373.378415
#
# Testing Function 13
# Iteration 0: Best fitness = 1456237489.321641, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 10341.388877, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 10065.790105, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 8825.551135, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 8817.117453, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 8817.117453, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 8710.429280, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 8710.429106, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 8709.904558, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 8709.885108, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 13 optimization complete:
# Best fitness: 8709.885108
# Distance from optimum: 7409.885108
#
# Testing Function 14
# Iteration 0: Best fitness = 148544.570935, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 2043.248706, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 1664.919993, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 1581.820528, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 1581.142832, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 1581.142832, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 1580.934026, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 1580.933944, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 1580.707257, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 1580.689980, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 14 optimization complete:
# Best fitness: 1580.572465
# Distance from optimum: 180.572465
#
# Testing Function 15
# Iteration 0: Best fitness = 1525062.360911, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 4312.974442, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 4312.974442, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 3568.813619, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 1756.918598, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 1756.916494, w = 0.5775, c1 = 1.5750, c2 = 1.1875
# Iteration 600: Best fitness = 1756.916494, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 1756.595903, w = 0.4305, c1 = 1.1550, c2 = 1.6625
# Iteration 800: Best fitness = 1756.595709, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 1756.239017, w = 0.2835, c1 = 0.7350, c2 = 2.1375
# Function 15 optimization complete:
# Best fitness: 1756.127496
# Distance from optimum: 256.127496
#
# Testing Function 16
# Iteration 0: Best fitness = 2909.555950, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 1799.430271, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 1654.691968, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 1645.794239, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 1642.866569, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 1641.740605, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 1640.292567, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 1640.257269, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 1640.051517, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 1640.008289, w = 0.2835, c1 = 0.7350, c2 = 2.1375
# Function 16 optimization complete:
# Best fitness: 1639.944442
# Distance from optimum: 39.944442
#
# Testing Function 17
# Iteration 0: Best fitness = nan, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# C:\Python310\lib\site-packages\cec2017-1.0-py3.10.egg\cec2017\basic.py:239: RuntimeWarning: invalid value encountered in divide
#   t = np.abs(tjx - np.round(tjx)) / tj
# Iteration 100: Best fitness = nan, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = nan, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = nan, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = nan, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = nan, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = nan, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = nan, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = nan, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = nan, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 17 optimization complete:
# Best fitness: nan
# Distance from optimum: nan
#
# Testing Function 18
# Iteration 0: Best fitness = 194146013.528365, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 2395.635378, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 2364.812156, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 2239.607465, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 2239.060049, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 2239.060049, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 2238.907390, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 2238.685173, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 2238.683370, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 2238.683360, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 18 optimization complete:
# Best fitness: 2238.505736
# Distance from optimum: 438.505736
#
# Testing Function 19
# Iteration 0: Best fitness = 223750540.186552, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 3687.586634, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 2407.019960, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 1945.639187, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 1945.070855, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 1945.065741, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 1945.064267, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 1945.064218, w = 0.4305, c1 = 1.1550, c2 = 1.6625
# Iteration 800: Best fitness = 1945.064218, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 1945.064217, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 19 optimization complete:
# Best fitness: 1945.064212
# Distance from optimum: 45.064212
#
# Testing Function 20
# Iteration 0: Best fitness = nan, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = nan, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = nan, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = nan, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = nan, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = nan, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = nan, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = nan, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = nan, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = nan, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 20 optimization complete:
# Best fitness: nan
# Distance from optimum: nan
#
# Testing Function 21
# Iteration 0: Best fitness = 2410.801696, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 2222.457705, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 900: Best fitness = 2900.260197, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 26 optimization complete:
# Best fitness: 2900.179606
# Distance from optimum: 300.179606
#
# Testing Function 27
# Iteration 0: Best fitness = 3303.458671, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 3103.194081, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 3101.842177, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 3101.842176, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = 3101.842176, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 3101.842176, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 3101.842176, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 3101.842176, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 3101.842176, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 3101.842176, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 27 optimization complete:
# Best fitness: 3101.842176
# Distance from optimum: 401.842176
#
# Testing Function 28
# Iteration 0: Best fitness = 3780.682160, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 3389.399351, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 3388.672835, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 3388.668714, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = 3388.668714, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 3388.668714, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 3388.621397, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 3388.621397, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 3388.621397, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 3388.621397, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 28 optimization complete:
# Best fitness: 3388.621397
# Distance from optimum: 588.621397
#
# Testing Function 29
# Iteration 0: Best fitness = nan, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = nan, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = nan, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = nan, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = nan, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = nan, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = nan, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = nan, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = nan, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = nan, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 29 optimization complete:
# Best fitness: nan
# Distance from optimum: nan
#
# Testing Function 30
# Iteration 0: Best fitness = 205546210.067219, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 8469095.093043, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 7645828.881428, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 4560514.426991, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 4560461.356623, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 4560461.356623, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 4425152.289327, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 4381901.263669, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 3669892.422965, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 3669891.402683, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 30 optimization complete:
# Best fitness: 3489845.649679
# Distance from optimum: 3486845.649679

# %%
import sys
sys.path.insert(1, '/kaggle/working/cec2017-py')

import numpy as np
import cec2017.functions as functions

    
def adaptive_pso(objective_func, dim, num_particles, max_iter, bounds=(-100, 100)):
    # Initialize particles and velocities
    particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
    velocities = np.random.uniform(-1, 1, (num_particles, dim))
    
    # Initialize personal best and global best
    pbest = particles.copy()
    pbest_fitness = np.array([objective_func(p) for p in pbest])
    gbest = pbest[np.argmin(pbest_fitness)]
    gbest_fitness = np.min(pbest_fitness)
    
    # PSO parameters
    w_max, w_min = 0.9, 0.2  # Inertia weight bounds
    c1_max, c1_min = 2.5, 0.5  # Cognitive parameter bounds
    c2_max, c2_min = 2.5, 0.  # Social parameter bounds
    
    # Adaptive parameter variables
    w = w_max
    c1 = c1_max
    c2 = c2_min
    
    # Variables for adaptation
    prev_best_fitness = gbest_fitness
    stagnation_counter = 0
    
    # Main PSO loop
    for iteration in range(max_iter):
        # Calculate progress
        progress = iteration / max_iter
        
        # Adapt parameters
        w = w_max - (w_max - w_min) * progress
        c1 = c1_max - (c1_max - c1_min) * progress
        c2 = c2_min + (c2_max - c2_min) * progress
        
        # Update velocities
        r1, r2 = np.random.rand(2)
        velocities = (w * velocities
                      + c1 * r1 * (pbest - particles)
                      + c2 * r2 * (gbest - particles))
        
        # Update particles
        particles += velocities
        
        # Apply bounds
        particles = np.clip(particles, bounds[0], bounds[1])
        
        # Evaluate fitness
        fitness = np.array([objective_func(p) for p in particles])
        
        # Update personal best
        improved = fitness < pbest_fitness
        pbest[improved] = particles[improved]
        pbest_fitness[improved] = fitness[improved]
        
        # Update global best
        if np.min(fitness) < gbest_fitness:
            gbest = particles[np.argmin(fitness)]
            gbest_fitness = np.min(fitness)
            stagnation_counter = 0
        else:
            stagnation_counter += 1
        
        # Adaptation based on improvement
        if gbest_fitness < prev_best_fitness:
            # If improving, increase exploration
            w = min(w_max, w * 1.05)
            c1 = min(c1_max, c1 * 1.05)
            c2 = max(c2_min, c2 * 0.95)
        else:
            # If stagnating, increase exploitation
            w = max(w_min, w * 0.95)
            c1 = max(c1_min, c1 * 0.95)
            c2 = min(c2_max, c2 * 1.05)
        
        # Store current best fitness for next iteration's comparison
        prev_best_fitness = gbest_fitness
        
        # Print progress
        #if iteration % 100 == 0:
            #print(f"Iteration {iteration}: Best fitness = {gbest_fitness:.6f}, w = {w:.4f}, c1 = {c1:.4f}, c2 = {c2:.4f}")
        
        # Optional: Reset if stagnation occurs for too long
        if stagnation_counter > 50:
            particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
            velocities = np.random.uniform(-1, 1, (num_particles, dim))
            stagnation_counter = 0
    
    return gbest, gbest_fitness

# Set parameters
dim = 10
num_particles = 100
max_iter = 1000
bounds = (-100, 100)
num_iterations = 10

# Test all 30 functions
for func_num in range(1, 31):
    print(f"\nTesting Function {func_num}")
    
    # Get the CEC2017 function
    cec_function = getattr(functions, f'f{func_num}')
    
    # Create a wrapper function to handle the different input format
    def objective_func(x):
        return cec_function(x.reshape(1, -1))[0]
    
    # Run 100 iterations
    results = []
    for _ in range(num_iterations):
        best_solution, best_fitness = adaptive_pso(objective_func, dim, num_particles, max_iter, bounds)
        results.append(best_fitness)
    
    # Calculate statistics
    mean_fitness = np.mean(results)
    median_fitness = np.median(results)
    best_fitness = np.min(results)
    worst_fitness = np.max(results)
    std_fitness = np.std(results)
    
    print(f"Function {func_num} optimization complete:")
    print(f"Mean fitness: {mean_fitness:.6f}")
    print(f"Median fitness: {median_fitness:.6f}")
    print(f"Best fitness: {best_fitness:.6f}")
    print(f"Worst fitness: {worst_fitness:.6f}")
    print(f"Standard deviation: {std_fitness:.6f}")
# Out:
# Testing Function 1
# Iteration 0: Best fitness = 151448488771.716644, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 36213927.732379, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 7996138.024781, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 7574978.621990, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 7574963.300119, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 7574963.300116, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 64794.830344, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 64794.829437, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 13450.998919, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 12203.740303, w = 0.2835, c1 = 0.7350, c2 = 2.1375
# Iteration 700: Best fitness = 424.578387, w = 0.4305, c1 = 1.1550, c2 = 1.6625
# Iteration 800: Best fitness = 423.614780, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 398.408488, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 120745.345212, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 1148.915575, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 656.863852, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 653.093855, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 653.093853, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 653.093853, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 340.587945, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 340.587942, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 317.432413, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 306.786712, w = 0.2835, c1 = 0.7350, c2 = 2.1375
# Function 3 optimization complete:
# Mean fitness: 336.814525
# Median fitness: 306.022900
# Best fitness: 300.012617
# Worst fitness: 481.948475
# Standard deviation: 57.196024
#
# Testing Function 4
# Iteration 0: Best fitness = 2138.876125, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 404.776835, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 404.427273, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 404.417006, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 404.417003, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 404.373765, w = 0.5775, c1 = 1.5750, c2 = 1.1875
# Iteration 600: Best fitness = 404.373153, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 404.347008, w = 0.4305, c1 = 1.1550, c2 = 1.6625
# Iteration 800: Best fitness = 404.346914, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 404.248490, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 3476.522137, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 442.458055, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 440.383572, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 440.383361, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 440.383361, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 410.580070, w = 0.5775, c1 = 1.5750, c2 = 1.1875
# Iteration 600: Best fitness = 410.580070, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 0: Best fitness = 1559.361853, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 407.937627, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 407.814438, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 407.785995, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 407.778499, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 407.778499, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 407.764344, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 407.699225, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 407.644127, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 407.617447, w = 0.2835, c1 = 0.7350, c2 = 2.1375
# Iteration 0: Best fitness = 1540.636458, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 400.049995, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 400.019976, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 400.019937, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 400.019937, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 400.019937, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 400.019465, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 400.019372, w = 0.4305, c1 = 1.1550, c2 = 1.6625
# Iteration 800: Best fitness = 400.019365, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 400.019274, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 4 optimization complete:
# Mean fitness: 405.882487
# Median fitness: 407.020609
# Best fitness: 400.019199
# Worst fitness: 408.445351
# Standard deviation: 2.817929
#
# Testing Function 5
# Iteration 0: Best fitness = 664.155269, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 564.870164, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 546.249132, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 533.093593, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 532.844857, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 532.844826, w = 0.5775, c1 = 1.5750, c2 = 1.1875
# Iteration 600: Best fitness = 532.833707, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 532.833576, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 532.833558, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 532.833547, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 400: Best fitness = 516.005688, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 516.005684, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 515.923591, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 515.923585, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 515.922479, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 515.922479, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 632.464191, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 548.596039, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 533.406473, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 532.834617, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 532.833903, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 532.833887, w = 0.5775, c1 = 1.5750, c2 = 1.1875
# Iteration 600: Best fitness = 532.833681, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 532.833681, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 532.833681, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 532.833681, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 602.532368, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 531.941127, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 521.901227, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 521.889329, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = 521.889315, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 521.889315, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 521.889096, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 521.889072, w = 0.4305, c1 = 1.1550, c2 = 1.6625
# Iteration 800: Best fitness = 521.889068, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 521.889066, w = 0.2835, c1 = 0.7350, c2 = 2.1375
# Function 5 optimization complete:
# Mean fitness: 523.381969
# Median fitness: 521.889060
# Best fitness: 510.946170
# Worst fitness: 537.808283
# Standard deviation: 8.314944
#
# Testing Function 6
# Iteration 0: Best fitness = 727.318827, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 613.696586, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 608.205256, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 605.272811, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = 604.755357, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 604.596178, w = 0.5775, c1 = 1.5750, c2 = 1.1875
# Iteration 600: Best fitness = 604.596178, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 604.431275, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 604.410043, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 604.410043, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 696.704792, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 647.357444, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 632.466428, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 631.683817, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 631.611881, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 631.606604, w = 0.5775, c1 = 1.5750, c2 = 1.1875
# Iteration 600: Best fitness = 631.606604, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 631.606296, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 631.521565, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 631.451189, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 686.339157, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 619.660478, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 609.499023, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 609.048009, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 609.044396, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 609.044396, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 609.044396, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 608.876889, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 608.876751, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 608.876751, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 697.189764, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 639.673438, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 623.560344, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 618.619887, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 618.547921, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 618.539903, w = 0.5775, c1 = 1.5750, c2 = 1.1875
# Iteration 800: Best fitness = 628.529982, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 628.529982, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 695.709773, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 651.783000, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 627.270520, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 626.684371, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = 626.509688, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 626.290257, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 626.290257, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 624.949079, w = 0.4305, c1 = 1.1550, c2 = 1.6625
# Iteration 800: Best fitness = 624.688049, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 624.644661, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 684.332485, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 619.085686, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 609.284084, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 605.932792, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 605.702139, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 605.702060, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 605.702059, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 605.702059, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 605.686670, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 605.686527, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 685.065716, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 625.727962, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 611.762690, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 611.358849, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = 611.002960, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 610.909062, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 610.909062, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 610.909062, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 610.901318, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 610.901028, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Function 6 optimization complete:
# Mean fitness: 615.660558
# Median fitness: 614.716345
# Best fitness: 602.245582
# Worst fitness: 631.451189
# Standard deviation: 10.053558
#
# Testing Function 7
# Iteration 0: Best fitness = 1098.733976, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 770.785497, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 749.446343, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 735.526977, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 735.465588, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 735.465570, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 735.465534, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 735.465533, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 735.465533, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 735.465533, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 1166.969496, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 775.508022, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 774.317031, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 774.317031, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = 748.576768, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 743.569765, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 743.548929, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 743.548929, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 740.307402, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 740.198646, w = 0.2835, c1 = 0.7350, c2 = 2.1375
# Iteration 0: Best fitness = 1163.519558, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 769.034703, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 764.904737, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 764.891451, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = 764.891451, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 764.891451, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 764.891449, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 764.891449, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 764.891449, w = 0.3570, c1 = 0.9450, c2 = 1.9000
# Iteration 900: Best fitness = 764.891449, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 1121.204189, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 761.244814, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 742.759602, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 740.048768, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = 737.810430, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 736.844498, w = 0.5775, c1 = 1.5750, c2 = 1.1875
# Iteration 600: Best fitness = 736.844496, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 736.835700, w = 0.4305, c1 = 1.1550, c2 = 1.6625
# Iteration 800: Best fitness = 736.835641, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 736.828773, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 1137.524152, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 743.337075, w = 0.8715, c1 = 2.4150, c2 = 0.2375
# Iteration 200: Best fitness = 733.056717, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 732.313239, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 732.313223, w = 0.5890, c1 = 1.6150, c2 = 1.0500
# Iteration 500: Best fitness = 732.313223, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 732.313197, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 732.313197, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 732.313196, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 732.313196, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 1178.082893, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 749.970985, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 725.286373, w = 0.7220, c1 = 1.9950, c2 = 0.5250
# Iteration 300: Best fitness = 719.646653, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 719.642111, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 719.642111, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 719.635785, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 719.635785, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 719.635262, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 719.634955, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 1017.362198, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 760.367661, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 732.984083, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 732.729860, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 732.725606, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 732.725606, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 732.721240, w = 0.4560, c1 = 1.2350, c2 = 1.5750
# Iteration 700: Best fitness = 732.719989, w = 0.4305, c1 = 1.1550, c2 = 1.6625
# Iteration 800: Best fitness = 732.719976, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 732.719897, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 1103.884625, w = 0.8550, c1 = 2.3750, c2 = 0.0000
# Iteration 100: Best fitness = 742.167422, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 722.882556, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 722.762222, w = 0.7245, c1 = 1.9950, c2 = 0.7125
# Iteration 400: Best fitness = 722.762109, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 722.762109, w = 0.5225, c1 = 1.4250, c2 = 1.3125
# Iteration 600: Best fitness = 722.761424, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 722.761422, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 722.761416, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 722.761410, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 1161.663793, w = 0.9000, c1 = 2.5000, c2 = 0.0000
# Iteration 100: Best fitness = 763.374160, w = 0.7885, c1 = 2.1850, c2 = 0.2625
# Iteration 200: Best fitness = 744.243970, w = 0.7980, c1 = 2.2050, c2 = 0.4750
# Iteration 300: Best fitness = 744.193595, w = 0.6555, c1 = 1.8050, c2 = 0.7875
# Iteration 400: Best fitness = 744.193575, w = 0.6510, c1 = 1.7850, c2 = 0.9500
# Iteration 500: Best fitness = 744.193548, w = 0.5775, c1 = 1.5750, c2 = 1.1875
# Iteration 600: Best fitness = 744.193489, w = 0.5040, c1 = 1.3650, c2 = 1.4250
# Iteration 700: Best fitness = 744.193471, w = 0.3895, c1 = 1.0450, c2 = 1.8375
# Iteration 800: Best fitness = 744.193470, w = 0.3230, c1 = 0.8550, c2 = 2.1000
# Iteration 900: Best fitness = 744.193470, w = 0.2565, c1 = 0.6650, c2 = 2.3625
# Iteration 0: Best fitness = 1123.810013, w = 0.9000, c1 = 2.5000, c2 = 0.0000

# %%
# Set parameters
dim = 10
num_particles = 100
max_iter = 1000
bounds = (-100, 100)
num_iterations = 10

import sys
sys.path.insert(1, '/kaggle/working/cec2017-py')

import numpy as np
import cec2017.functions as functions

    
def adaptive_pso(objective_func, dim, num_particles, max_iter, bounds=(-100, 100)):
    # Initialize particles and velocities
    particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
    velocities = np.random.uniform(-1, 1, (num_particles, dim))
    
    # Initialize personal best and global best
    pbest = particles.copy()
    pbest_fitness = np.array([objective_func(p) for p in pbest])
    gbest = pbest[np.argmin(pbest_fitness)]
    gbest_fitness = np.min(pbest_fitness)
    
    # PSO parameters
    w_max, w_min = 0.9, 0.2  # Inertia weight bounds
    c1_max, c1_min = 2.5, 0.5  # Cognitive parameter bounds
    c2_max, c2_min = 2.5, 0.  # Social parameter bounds
    
    # Adaptive parameter variables
    w = w_max
    c1 = c1_max
    c2 = c2_min
    
    # Variables for adaptation
    prev_best_fitness = gbest_fitness
    stagnation_counter = 0
    
    # Main PSO loop
    for iteration in range(max_iter):
        # Calculate progress
        progress = iteration / max_iter
        
        # Adapt parameters
        w = w_max - (w_max - w_min) * progress
        c1 = c1_max - (c1_max - c1_min) * progress
        c2 = c2_min + (c2_max - c2_min) * progress
        
        # Update velocities
        r1, r2 = np.random.rand(2)
        velocities = (w * velocities
                      + c1 * r1 * (pbest - particles)
                      + c2 * r2 * (gbest - particles))
        
        # Update particles
        particles += velocities
        
        # Apply bounds
        particles = np.clip(particles, bounds[0], bounds[1])
        
        # Evaluate fitness
        fitness = np.array([objective_func(p) for p in particles])
        
        # Update personal best
        improved = fitness < pbest_fitness
        pbest[improved] = particles[improved]
        pbest_fitness[improved] = fitness[improved]
        
        # Update global best
        if np.min(fitness) < gbest_fitness:
            gbest = particles[np.argmin(fitness)]
            gbest_fitness = np.min(fitness)
            stagnation_counter = 0
        else:
            stagnation_counter += 1
        
        # Adaptation based on improvement
        if gbest_fitness < prev_best_fitness:
            # If improving, increase exploration
            w = min(w_max, w * 1.05)
            c1 = min(c1_max, c1 * 1.05)
            c2 = max(c2_min, c2 * 0.95)
        else:
            # If stagnating, increase exploitation
            w = max(w_min, w * 0.95)
            c1 = max(c1_min, c1 * 0.95)
            c2 = min(c2_max, c2 * 1.05)
        
        # Store current best fitness for next iteration's comparison
        prev_best_fitness = gbest_fitness
        
        # Print progress
        #if iteration % 100 == 0:
            #print(f"Iteration {iteration}: Best fitness = {gbest_fitness:.6f}, w = {w:.4f}, c1 = {c1:.4f}, c2 = {c2:.4f}")
        
        # Optional: Reset if stagnation occurs for too long
        if stagnation_counter > 50:
            particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
            velocities = np.random.uniform(-1, 1, (num_particles, dim))
            stagnation_counter = 0
    
    return gbest, gbest_fitness


# Test all 30 functions
for func_num in range(1, 31):
    print(f"\nTesting Function {func_num}")
    
    # Get the CEC2017 function
    cec_function = getattr(functions, f'f{func_num}')
    
    # Create a wrapper function to handle the different input format
    def objective_func(x):
        return cec_function(x.reshape(1, -1))[0]
    
    # Run 10 iterations
    results = []
    for i in range(num_iterations):
        best_solution, best_fitness = adaptive_pso(objective_func, dim, num_particles, max_iter, bounds)
        results.append(best_fitness)
        print(f"Run {i+1}: Final fitness (iteration 1000) = {best_fitness:.6f}")
    
    # Calculate statistics
    mean_fitness = np.mean(results)
    median_fitness = np.median(results)
    best_fitness = np.min(results)
    worst_fitness = np.max(results)
    std_fitness = np.std(results)
    
    print(f"\nFunction {func_num} optimization complete:")
    print(f"Mean fitness: {mean_fitness:.6f}")
    print(f"Median fitness: {median_fitness:.6f}")
    print(f"Best fitness: {best_fitness:.6f}")
    print(f"Worst fitness: {worst_fitness:.6f}")
    print(f"Standard deviation: {std_fitness:.6f}")
# Out:
# Testing Function 1
# Run 1: Final fitness (iteration 1000) = 4389.643698
# Run 2: Final fitness (iteration 1000) = 2740.436495
# Run 3: Final fitness (iteration 1000) = 1407.238008
# Run 4: Final fitness (iteration 1000) = 8173.325801
# Run 5: Final fitness (iteration 1000) = 1464.949517
# Run 6: Final fitness (iteration 1000) = 1121.192769
# Run 7: Final fitness (iteration 1000) = 1956334.632095
# Run 8: Final fitness (iteration 1000) = 5155.924220
# Run 9: Final fitness (iteration 1000) = 1243.006523
# Run 10: Final fitness (iteration 1000) = 1045.176700
#
# Function 1 optimization complete:
# Mean fitness: 198307.552583
# Median fitness: 2102.693006
# Best fitness: 1045.176700
# Worst fitness: 1956334.632095
# Standard deviation: 586013.184606
#
# Testing Function 2
# WARNING: f2 has been deprecated from the CEC 2017 benchmark suite
# Run 1: Final fitness (iteration 1000) = 2105.750930
# Run 2: Final fitness (iteration 1000) = 108058.264575
# Run 3: Final fitness (iteration 1000) = 366.375323
# Run 4: Final fitness (iteration 1000) = 675.195418
# Run 5: Final fitness (iteration 1000) = 9917.519476
# Run 6: Final fitness (iteration 1000) = 767.279122
# Run 7: Final fitness (iteration 1000) = 100535.439335
# Run 8: Final fitness (iteration 1000) = 6556.617258
# Run 9: Final fitness (iteration 1000) = 6595.112090
# Run 10: Final fitness (iteration 1000) = 1699.370612
#
# Function 2 optimization complete:
# Mean fitness: 23727.692414
# Median fitness: 4331.184094
# Best fitness: 366.375323
# Worst fitness: 108058.264575
# Standard deviation: 40431.759846
#
# Testing Function 3
# Run 1: Final fitness (iteration 1000) = 300.010317
# Run 2: Final fitness (iteration 1000) = 309.855909
# Run 3: Final fitness (iteration 1000) = 313.675924
# Run 4: Final fitness (iteration 1000) = 310.621704
# Run 5: Final fitness (iteration 1000) = 300.059961
# Run 6: Final fitness (iteration 1000) = 321.273588
# Run 7: Final fitness (iteration 1000) = 318.545579
# Run 8: Final fitness (iteration 1000) = 305.727262
# Run 9: Final fitness (iteration 1000) = 300.124506
# Run 10: Final fitness (iteration 1000) = 321.899752
#
# Function 3 optimization complete:
# Mean fitness: 310.179450
# Median fitness: 310.238807
# Best fitness: 300.010317
# Worst fitness: 321.899752
# Standard deviation: 8.183534
#
# Testing Function 4
# Run 1: Final fitness (iteration 1000) = 406.180313
# Run 2: Final fitness (iteration 1000) = 468.135506
# Run 3: Final fitness (iteration 1000) = 408.304084
# Run 4: Final fitness (iteration 1000) = 405.712247
# Run 5: Final fitness (iteration 1000) = 407.099624
# Run 6: Final fitness (iteration 1000) = 406.190384
# Run 7: Final fitness (iteration 1000) = 403.319277
# Run 8: Final fitness (iteration 1000) = 408.303379
# Run 9: Final fitness (iteration 1000) = 403.721082
# Run 10: Final fitness (iteration 1000) = 403.253969
#
# Function 4 optimization complete:
# Mean fitness: 412.021987
# Median fitness: 406.185348
# Best fitness: 403.253969
# Worst fitness: 468.135506
# Standard deviation: 18.788490
#
# Testing Function 5
# Run 1: Final fitness (iteration 1000) = 521.889059
# Run 2: Final fitness (iteration 1000) = 513.929434
# Run 3: Final fitness (iteration 1000) = 521.889069
# Run 4: Final fitness (iteration 1000) = 540.793175
# Run 5: Final fitness (iteration 1000) = 523.878992
# Run 6: Final fitness (iteration 1000) = 527.858742
# Run 7: Final fitness (iteration 1000) = 523.878992
# Run 8: Final fitness (iteration 1000) = 512.934471
# Run 9: Final fitness (iteration 1000) = 520.894108
# Run 10: Final fitness (iteration 1000) = 523.878912
#
# Function 5 optimization complete:
# Mean fitness: 523.182495
# Median fitness: 522.883991
# Best fitness: 512.934471
# Worst fitness: 540.793175
# Standard deviation: 7.298509
#
# Testing Function 6
# Run 1: Final fitness (iteration 1000) = 605.159141
# Run 2: Final fitness (iteration 1000) = 618.995319
# Run 3: Final fitness (iteration 1000) = 619.880730
# Run 4: Final fitness (iteration 1000) = 607.795011
# Run 5: Final fitness (iteration 1000) = 624.748373
# Run 6: Final fitness (iteration 1000) = 603.804610
# Run 7: Final fitness (iteration 1000) = 615.992891
# Run 8: Final fitness (iteration 1000) = 606.633327
# Run 9: Final fitness (iteration 1000) = 604.931659
# Run 10: Final fitness (iteration 1000) = 602.762472
#
# Function 6 optimization complete:
# Mean fitness: 611.070353
# Median fitness: 607.214169
# Best fitness: 602.762472
# Worst fitness: 624.748373
# Standard deviation: 7.593421
#
# Testing Function 7
# Run 1: Final fitness (iteration 1000) = 735.412837
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <module>
#     118 results = []
#     119 for i in range(num_iterations):
# --> 120     best_solution, best_fitness = adaptive_pso(objective_func, dim, num_particles, max_iter, bounds)
#     121     results.append(best_fitness)
#     122     print(f"Run {i+1}: Final fitness (iteration 1000) = {best_fitness:.6f}")
#
# Input In [1], in adaptive_pso(objective_func, dim, num_particles, max_iter, bounds)
#      60 particles = np.clip(particles, bounds[0], bounds[1])
#      62 # Evaluate fitness
# ---> 63 fitness = np.array([objective_func(p) for p in particles])
#      65 # Update personal best
#      66 improved = fitness < pbest_fitness
#
# Input In [1], in <listcomp>(.0)
#      60 particles = np.clip(particles, bounds[0], bounds[1])
#      62 # Evaluate fitness
# ---> 63 fitness = np.array([objective_func(p) for p in particles])
#      65 # Update personal best
#      66 improved = fitness < pbest_fitness
#
# Input In [1], in objective_func(x)
#     114 def objective_func(x):
# --> 115     return cec_function(x.reshape(1, -1))[0]
#
# File C:\Python310\lib\site-packages\cec2017-1.0-py3.10.egg\cec2017\simple.py:167, in f7(x, rotation, shift)
#     165     shift = transforms.shifts[6][:nx]
#     166 # pass the shift and rotation directly to the function
# --> 167 return basic.lunacek_bi_rastrigin(x, shift, rotation) + 700.0
#
# File C:\Python310\lib\site-packages\cec2017-1.0-py3.10.egg\cec2017\basic.py:82, in lunacek_bi_rastrigin(x, shift, rotation)
#      79 tmpx = 2 * y
#      80 tmpx[:, shift[0] < 0] *= -1
# ---> 82 z = tmpx.copy()
#      83 tmpx = tmpx + mu0
#      85 t1 = tmpx - mu0
#
# KeyboardInterrupt:

# %%
# Set parameters
dim = 10
num_particles = 100
max_iter = 1000
bounds = (-100, 100)
num_iterations = 10

import sys
sys.path.insert(1, '/kaggle/working/cec2017-py')

import numpy as np
import cec2017.functions as functions

    
def adaptive_pso(objective_func, dim, num_particles, max_iter, bounds=(-100, 100)):
    # Initialize particles and velocities
    particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
    velocities = np.random.uniform(-1, 1, (num_particles, dim))
    
    # Initialize personal best and global best
    pbest = particles.copy()
    pbest_fitness = np.array([objective_func(p) for p in pbest])
    gbest = pbest[np.argmin(pbest_fitness)]
    gbest_fitness = np.min(pbest_fitness)
    
    # PSO parameters
    w_max, w_min = 0.9, 0.1  # Inertia weight bounds
    c1_max, c1_min = 2.8, 0.2  # Cognitive parameter bounds
    c2_max, c2_min = 2.8, 0.2  # Social parameter bounds
    
    # Adaptive parameter variables
    w = w_max
    c1 = c1_max
    c2 = c2_min
    
    # Variables for adaptation
    prev_best_fitness = gbest_fitness
    stagnation_counter = 0
    
    # Main PSO loop
    for iteration in range(max_iter):
        # Calculate progress
        progress = iteration / max_iter
        
        # Adapt parameters
        w = w_max - (w_max - w_min) * progress
        c1 = c1_max - (c1_max - c1_min) * progress
        c2 = c2_min + (c2_max - c2_min) * progress
        
        # Update velocities
        r1, r2 = np.random.rand(2)
        velocities = (w * velocities
                      + c1 * r1 * (pbest - particles)
                      + c2 * r2 * (gbest - particles))
        
        # Update particles
        particles += velocities
        
        # Apply bounds
        particles = np.clip(particles, bounds[0], bounds[1])
        
        # Evaluate fitness
        fitness = np.array([objective_func(p) for p in particles])
        
        # Update personal best
        improved = fitness < pbest_fitness
        pbest[improved] = particles[improved]
        pbest_fitness[improved] = fitness[improved]
        
        # Update global best
        if np.min(fitness) < gbest_fitness:
            gbest = particles[np.argmin(fitness)]
            gbest_fitness = np.min(fitness)
            stagnation_counter = 0
        else:
            stagnation_counter += 1
        
        # Adaptation based on improvement
        if gbest_fitness < prev_best_fitness:
            # If improving, increase exploration
            w = min(w_max, w * 1.05)
            c1 = min(c1_max, c1 * 1.05)
            c2 = max(c2_min, c2 * 0.95)
        else:
            # If stagnating, increase exploitation
            w = max(w_min, w * 0.95)
            c1 = max(c1_min, c1 * 0.95)
            c2 = min(c2_max, c2 * 1.05)
        
        # Store current best fitness for next iteration's comparison
        prev_best_fitness = gbest_fitness
        
        # Print progress
        #if iteration % 100 == 0:
            #print(f"Iteration {iteration}: Best fitness = {gbest_fitness:.6f}, w = {w:.4f}, c1 = {c1:.4f}, c2 = {c2:.4f}")
        
        # Optional: Reset if stagnation occurs for too long
        if stagnation_counter > 50:
            particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
            velocities = np.random.uniform(-1, 1, (num_particles, dim))
            stagnation_counter = 0
    
    return gbest, gbest_fitness, w, c1, c2


# Set parameters
dim = 10
num_particles = 100
max_iter = 1000
bounds = (-100, 100)
num_iterations = 1

# Test all 30 functions
for func_num in range(1, 31):
    print(f"\nTesting Function {func_num}")
    
    # Get the CEC2017 function
    cec_function = getattr(functions, f'f{func_num}')
    
    # Create a wrapper function to handle the different input format
    def objective_func(x):
        return cec_function(x.reshape(1, -1))[0]
    
    # Run 10 iterations
    results = []
    distances = []
    for i in range(num_iterations):
        best_solution, best_fitness, final_w, final_c1, final_c2 = adaptive_pso(objective_func, dim, num_particles, max_iter, bounds)
        distance = abs(best_fitness - func_num * 100)
        results.append(best_fitness)
        distances.append(distance)
        print(f"Run {i+1}: Final fitness = {best_fitness:.6f}, Distance from optimum = {distance:.6f}, Final parameters: w = {final_w:.3f}, c1 = {final_c1:.3f}, c2 = {final_c2:.3f}")
    
    # Calculate statistics
    mean_fitness = np.mean(results)
    median_fitness = np.median(results)
    best_fitness = np.min(results)
    worst_fitness = np.max(results)
    std_fitness = np.std(results)
    best_distance = np.min(distances)
    
    print(f"\nFunction {func_num} optimization complete:")
    print(f"Mean fitness: {mean_fitness:.6f}")
    print(f"Median fitness: {median_fitness:.6f}")
    print(f"Best fitness: {best_fitness:.6f}")
    print(f"Worst fitness: {worst_fitness:.6f}")
    print(f"Standard deviation: {std_fitness:.6f}")
    print(f"Best distance from optimum: {best_distance:.6f}")
# Out:
# Testing Function 1
# Run 1: Final fitness = 1154.141904, Distance from optimum = 1054.141904, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 1 optimization complete:
# Mean fitness: 1154.141904
# Median fitness: 1154.141904
# Best fitness: 1154.141904
# Worst fitness: 1154.141904
# Standard deviation: 0.000000
# Best distance from optimum: 1054.141904
#
# Testing Function 2
# WARNING: f2 has been deprecated from the CEC 2017 benchmark suite
# Run 1: Final fitness = 9683.099737, Distance from optimum = 9483.099737, Final parameters: w = 0.106, c1 = 0.213, c2 = 2.658
#
# Function 2 optimization complete:
# Mean fitness: 9683.099737
# Median fitness: 9683.099737
# Best fitness: 9683.099737
# Worst fitness: 9683.099737
# Standard deviation: 0.000000
# Best distance from optimum: 9483.099737
#
# Testing Function 3
# Run 1: Final fitness = 345.040167, Distance from optimum = 45.040167, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 3 optimization complete:
# Mean fitness: 345.040167
# Median fitness: 345.040167
# Best fitness: 345.040167
# Worst fitness: 345.040167
# Standard deviation: 0.000000
# Best distance from optimum: 45.040167
#
# Testing Function 4
# Run 1: Final fitness = 408.303368, Distance from optimum = 8.303368, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 4 optimization complete:
# Mean fitness: 408.303368
# Median fitness: 408.303368
# Best fitness: 408.303368
# Worst fitness: 408.303368
# Standard deviation: 0.000000
# Best distance from optimum: 8.303368
#
# Testing Function 5
# Run 1: Final fitness = 526.863859, Distance from optimum = 26.863859, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 5 optimization complete:
# Mean fitness: 526.863859
# Median fitness: 526.863859
# Best fitness: 526.863859
# Worst fitness: 526.863859
# Standard deviation: 0.000000
# Best distance from optimum: 26.863859
#
# Testing Function 6
# Run 1: Final fitness = 602.366154, Distance from optimum = 2.366154, Final parameters: w = 0.106, c1 = 0.213, c2 = 2.658
#
# Function 6 optimization complete:
# Mean fitness: 602.366154
# Median fitness: 602.366154
# Best fitness: 602.366154
# Worst fitness: 602.366154
# Standard deviation: 0.000000
# Best distance from optimum: 2.366154
#
# Testing Function 7
# Run 1: Final fitness = 742.654345, Distance from optimum = 42.654345, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 7 optimization complete:
# Mean fitness: 742.654345
# Median fitness: 742.654345
# Best fitness: 742.654345
# Worst fitness: 742.654345
# Standard deviation: 0.000000
# Best distance from optimum: 42.654345
#
# Testing Function 8
# Run 1: Final fitness = 825.868870, Distance from optimum = 25.868870, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 8 optimization complete:
# Mean fitness: 825.868870
# Median fitness: 825.868870
# Best fitness: 825.868870
# Worst fitness: 825.868870
# Standard deviation: 0.000000
# Best distance from optimum: 25.868870
#
# Testing Function 9
# Run 1: Final fitness = 902.735463, Distance from optimum = 2.735463, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 9 optimization complete:
# Mean fitness: 902.735463
# Median fitness: 902.735463
# Best fitness: 902.735463
# Worst fitness: 902.735463
# Standard deviation: 0.000000
# Best distance from optimum: 2.735463
#
# Testing Function 10
# Run 1: Final fitness = 1688.330265, Distance from optimum = 688.330265, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 10 optimization complete:
# Mean fitness: 1688.330265
# Median fitness: 1688.330265
# Best fitness: 1688.330265
# Worst fitness: 1688.330265
# Standard deviation: 0.000000
# Best distance from optimum: 688.330265
#
# Testing Function 11
# Run 1: Final fitness = 1126.928314, Distance from optimum = 26.928314, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 11 optimization complete:
# Mean fitness: 1126.928314
# Median fitness: 1126.928314
# Best fitness: 1126.928314
# Worst fitness: 1126.928314
# Standard deviation: 0.000000
# Best distance from optimum: 26.928314
#
# Testing Function 12
# Run 1: Final fitness = 33242.983393, Distance from optimum = 32042.983393, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 12 optimization complete:
# Mean fitness: 33242.983393
# Median fitness: 33242.983393
# Best fitness: 33242.983393
# Worst fitness: 33242.983393
# Standard deviation: 0.000000
# Best distance from optimum: 32042.983393
#
# Testing Function 13
# Run 1: Final fitness = 4182.596016, Distance from optimum = 2882.596016, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 13 optimization complete:
# Mean fitness: 4182.596016
# Median fitness: 4182.596016
# Best fitness: 4182.596016
# Worst fitness: 4182.596016
# Standard deviation: 0.000000
# Best distance from optimum: 2882.596016
#
# Testing Function 14
# Run 1: Final fitness = 1541.602735, Distance from optimum = 141.602735, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 14 optimization complete:
# Mean fitness: 1541.602735
# Median fitness: 1541.602735
# Best fitness: 1541.602735
# Worst fitness: 1541.602735
# Standard deviation: 0.000000
# Best distance from optimum: 141.602735
#
# Testing Function 15
# Run 1: Final fitness = 4110.493509, Distance from optimum = 2610.493509, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 15 optimization complete:
# Mean fitness: 4110.493509
# Median fitness: 4110.493509
# Best fitness: 4110.493509
# Worst fitness: 4110.493509
# Standard deviation: 0.000000
# Best distance from optimum: 2610.493509
#
# Testing Function 16
# Run 1: Final fitness = 1651.460075, Distance from optimum = 51.460075, Final parameters: w = 0.106, c1 = 0.213, c2 = 2.658
#
# Function 16 optimization complete:
# Mean fitness: 1651.460075
# Median fitness: 1651.460075
# Best fitness: 1651.460075
# Worst fitness: 1651.460075
# Standard deviation: 0.000000
# Best distance from optimum: 51.460075
#
# Testing Function 17
# C:\Python310\lib\site-packages\cec2017-1.0-py3.10.egg\cec2017\basic.py:239: RuntimeWarning: invalid value encountered in divide
#   t = np.abs(tjx - np.round(tjx)) / tj
# Run 1: Final fitness = nan, Distance from optimum = nan, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 17 optimization complete:
# Mean fitness: nan
# Median fitness: nan
# Best fitness: nan
# Worst fitness: nan
# Standard deviation: nan
# Best distance from optimum: nan
#
# Testing Function 18
# Run 1: Final fitness = 35032.028243, Distance from optimum = 33232.028243, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 18 optimization complete:
# Mean fitness: 35032.028243
# Median fitness: 35032.028243
# Best fitness: 35032.028243
# Worst fitness: 35032.028243
# Standard deviation: 0.000000
# Best distance from optimum: 33232.028243
#
# Testing Function 19
# Run 1: Final fitness = 2024.540498, Distance from optimum = 124.540498, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 19 optimization complete:
# Mean fitness: 2024.540498
# Median fitness: 2024.540498
# Best fitness: 2024.540498
# Worst fitness: 2024.540498
# Standard deviation: 0.000000
# Best distance from optimum: 124.540498
#
# Testing Function 20
# Run 1: Final fitness = nan, Distance from optimum = nan, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 20 optimization complete:
# Mean fitness: nan
# Median fitness: nan
# Best fitness: nan
# Worst fitness: nan
# Standard deviation: nan
# Best distance from optimum: nan
#
# Testing Function 21
# Run 1: Final fitness = 2323.218514, Distance from optimum = 223.218514, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 21 optimization complete:
# Mean fitness: 2323.218514
# Median fitness: 2323.218514
# Best fitness: 2323.218514
# Worst fitness: 2323.218514
# Standard deviation: 0.000000
# Best distance from optimum: 223.218514
#
# Testing Function 22
# Run 1: Final fitness = 2318.566425, Distance from optimum = 118.566425, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 22 optimization complete:
# Mean fitness: 2318.566425
# Median fitness: 2318.566425
# Best fitness: 2318.566425
# Worst fitness: 2318.566425
# Standard deviation: 0.000000
# Best distance from optimum: 118.566425
#
# Testing Function 23
# Run 1: Final fitness = 2639.995788, Distance from optimum = 339.995788, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 23 optimization complete:
# Mean fitness: 2639.995788
# Median fitness: 2639.995788
# Best fitness: 2639.995788
# Worst fitness: 2639.995788
# Standard deviation: 0.000000
# Best distance from optimum: 339.995788
#
# Testing Function 24
# Run 1: Final fitness = 2772.777005, Distance from optimum = 372.777005, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 24 optimization complete:
# Mean fitness: 2772.777005
# Median fitness: 2772.777005
# Best fitness: 2772.777005
# Worst fitness: 2772.777005
# Standard deviation: 0.000000
# Best distance from optimum: 372.777005
#
# Testing Function 25
# Run 1: Final fitness = 2944.193858, Distance from optimum = 444.193858, Final parameters: w = 0.106, c1 = 0.213, c2 = 2.658
#
# Function 25 optimization complete:
# Mean fitness: 2944.193858
# Median fitness: 2944.193858
# Best fitness: 2944.193858
# Worst fitness: 2944.193858
# Standard deviation: 0.000000
# Best distance from optimum: 444.193858
#
# Testing Function 26
# Run 1: Final fitness = 3094.791530, Distance from optimum = 494.791530, Final parameters: w = 0.106, c1 = 0.213, c2 = 2.658
#
# Function 26 optimization complete:
# Mean fitness: 3094.791530
# Median fitness: 3094.791530
# Best fitness: 3094.791530
# Worst fitness: 3094.791530
# Standard deviation: 0.000000
# Best distance from optimum: 494.791530
#
# Testing Function 27
# Run 1: Final fitness = 3103.337739, Distance from optimum = 403.337739, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 27 optimization complete:
# Mean fitness: 3103.337739
# Median fitness: 3103.337739
# Best fitness: 3103.337739
# Worst fitness: 3103.337739
# Standard deviation: 0.000000
# Best distance from optimum: 403.337739
#
# Testing Function 28
# Run 1: Final fitness = 3309.678921, Distance from optimum = 509.678921, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 28 optimization complete:
# Mean fitness: 3309.678921
# Median fitness: 3309.678921
# Best fitness: 3309.678921
# Worst fitness: 3309.678921
# Standard deviation: 0.000000
# Best distance from optimum: 509.678921
#
# Testing Function 29
# Run 1: Final fitness = nan, Distance from optimum = nan, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 29 optimization complete:
# Mean fitness: nan
# Median fitness: nan
# Best fitness: nan
# Worst fitness: nan
# Standard deviation: nan
# Best distance from optimum: nan
#
# Testing Function 30
# Run 1: Final fitness = 5073.127631, Distance from optimum = 2073.127631, Final parameters: w = 0.100, c1 = 0.200, c2 = 2.800
#
# Function 30 optimization complete:
# Mean fitness: 5073.127631
# Median fitness: 5073.127631
# Best fitness: 5073.127631
# Worst fitness: 5073.127631
# Standard deviation: 0.000000
# Best distance from optimum: 2073.127631
