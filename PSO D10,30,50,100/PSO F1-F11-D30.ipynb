# %%
import sys
sys.path.insert(1, '/kaggle/working/cec2017-py')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import cec2017.functions as functions

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
 
def standard_pso(objective_func, dim, num_particles, max_iter, bounds=(-100, 100)):
    # Initialize particles and velocities
    particles = np.random.uniform(bounds[0], bounds[1], (num_particles, dim))
    velocities = np.random.uniform(-1, 1, (num_particles, dim))
    
    # Initialize personal best and global best
    pbest = particles.copy()
    pbest_fitness = np.array([objective_func(p) for p in pbest])
    gbest = pbest[np.argmin(pbest_fitness)]
    gbest_fitness = np.min(pbest_fitness)
    
    # PSO parameters (constant for standard PSO)
    w = 0.7  # Inertia weight
    c1 = 2  # Cognitive parameter
    c2 = 2  # Social parameter
    
    convergence = []
    
    # Main PSO loop
    for iteration in range(max_iter):
        # Update velocities
        r1, r2 = np.random.rand(2)
        velocities = (w * velocities
                      + c1 * r1 * (pbest - particles)
                      + c2 * r2 * (gbest - particles))
        
        # Update particles
        particles += velocities
        
        # Apply bounds
        particles = np.clip(particles, bounds[0], bounds[1])
        
        # Evaluate fitness
        fitness = np.array([objective_func(p) for p in particles])
        
        # Update personal best
        improved = fitness < pbest_fitness
        pbest[improved] = particles[improved]
        pbest_fitness[improved] = fitness[improved]
        
        # Update global best
        if np.min(fitness) < gbest_fitness:
            gbest = particles[np.argmin(fitness)]
            gbest_fitness = np.min(fitness)
        
        convergence.append(gbest_fitness)
        
        # Print progress (commented out to match your code)
        if iteration % 250 == 0:
            pass
            #print(f"Iteration {iteration}: Best fitness = {gbest_fitness:.6f}")
    
    return gbest, gbest_fitness, w, c1, c2, convergence


# Set parameters
dim = 30
num_particles = 100
max_iter = 1000
bounds = (-100, 100)
num_iterations = 10

# List to store results for all functions
all_results = []

# Test all 30 functions
for func_num in range(1, 11):
    print(f"\nTesting Function {func_num}")
    
    # Get the CEC2017 function
    cec_function = getattr(functions, f'f{func_num}')
    
    # Create a wrapper function to handle the different input format
    def objective_func(x):
        return cec_function(x.reshape(1, -1))[0]
    
    # Run iterations
    results = []
    distances = []
    all_convergences = []
    for i in range(num_iterations):
        best_solution, best_fitness, final_w, final_c1, final_c2, convergence = standard_pso(objective_func, dim, num_particles, max_iter, bounds)
        distance = abs(best_fitness - func_num * 100)
        results.append(best_fitness)
        distances.append(distance)
        all_convergences.append(convergence)
        #print(f"Run {i+1}: Final fitness = {best_fitness:.6f}, Distance from optimum = {distance:.6f}, Final parameters: w = {final_w:.3f}, c1 = {final_c1:.3f}, c2 = {final_c2:.3f}")
    
    # Calculate statistics
    mean_fitness = np.mean(results)
    median_fitness = np.median(results)
    best_fitness = np.min(results)
    worst_fitness = np.max(results)
    std_fitness = np.std(results)
    best_distance = np.min(distances)
    worst_distance = np.max(distances)
    mean_distance = np.mean(distances)
    median_distance = np.median(distances)
    std_distance = np.std(distances)
    
    # Store results for this function
    all_results.append([best_fitness, worst_fitness, median_fitness, mean_fitness, std_fitness])
    
    print(f"\nFunction {func_num} optimization complete:")
    print(f"Mean fitness: {mean_fitness:.6f}")
    print(f"Median fitness: {median_fitness:.6f}")
    print(f"Best fitness: {best_fitness:.6f}")
    print(f"Worst fitness: {worst_fitness:.6f}")
    print(f"Standard deviation: {std_fitness:.6f}")
    print(f"Best distance from optimum (ERROR): {best_distance:.6f} / {best_distance:.6E}")
    print(f"Worst distance from optimum (ERROR): {worst_distance:.6f} / {worst_distance:.6E}")
    print(f"Mean distance from optimum (ERROR): {mean_distance:.6f} / {mean_distance:.6E}")
    print(f"Median distance from optimum (ERROR): {median_distance:.6f} / {median_distance:.6E}")
    print(f"STD distance distance from optimum (ERROR): {std_distance:.6f} / {std_distance:.6E}")
    
    
    # Plot convergence
    plt.figure(figsize=(10, 6))
    for i, conv in enumerate(all_convergences):
        plt.plot(conv, label=f'Run {i+1}')
    plt.title(f'Convergence Plot for Function {func_num}')
    plt.xlabel('Iteration')
    plt.ylabel('Best Fitness')
    #plt.legend()
    plt.yscale('log')  # Use log scale for y-axis to better visualize improvements
    plt.grid(True)
    plt.show()
    
    # Set the style
    plt.style.use('seaborn-whitegrid')

    # Create the figure and axis objects
    fig, ax = plt.subplots(figsize=(12, 7))

    # Convert all_convergences to a numpy array
    convergences_array = np.array(all_convergences)

    # Calculate median, 25th and 75th percentiles
    median_convergence = np.median(convergences_array, axis=0)
    mean_convergence = np.mean(convergences_array, axis=0)
    percentile_25 = np.percentile(convergences_array, 25, axis=0)
    percentile_75 = np.percentile(convergences_array, 75, axis=0)

    # Plot the median convergence
    ax.plot(median_convergence, color='black', linewidth=2, label='Median')
    ax.plot(mean_convergence, color='blue', linewidth=2, label='Mean')

    # Plot the shaded area for the interquartile range
    ax.fill_between(range(len(median_convergence)), 
                    percentile_25,
                    percentile_75,
                    color='blue', alpha=0.2, label='25th-75th percentile')

    # Optionally, plot the best and worst runs
    best_run = np.min(convergences_array, axis=0)
    worst_run = np.max(convergences_array, axis=0)
    ax.plot(best_run, color='green', linewidth=1, alpha=0.7, label='Best run')
    ax.plot(worst_run, color='red', linewidth=1, alpha=0.7, label='Worst run')

    # Customize the plot
    ax.set_title(f'Convergence Plot for Function {func_num}', fontsize=16, fontweight='bold')
    ax.set_xlabel('Iteration', fontsize=12)
    ax.set_ylabel('Best Fitness', fontsize=12)
    ax.set_yscale('log')
    ax.grid(True, which="both", ls="-", alpha=0.2)
    ax.tick_params(axis='both', which='major', labelsize=10)

    # Customize the legend
    ax.legend(fontsize=10, loc='upper right')

    # Improve the layout
    plt.tight_layout()

    # Show the plot
    plt.show()
# Out:
# Testing Function 1
#
# Function 1 optimization complete:
# Mean fitness: 167517618408.678741
# Median fitness: 173074909576.411255
# Best fitness: 12217898519.109213
# Worst fitness: 338977631685.522156
# Standard deviation: 120513380086.330872
# Best distance from optimum (ERROR): 12217898419.109213 / 1.221790E+10
# Worst distance from optimum (ERROR): 338977631585.522156 / 3.389776E+11
# Mean distance from optimum (ERROR): 167517618308.678741 / 1.675176E+11
# Median distance from optimum (ERROR): 173074909476.411255 / 1.730749E+11
# STD distance distance from optimum (ERROR): 120513380086.330872 / 1.205134E+11
# Testing Function 2
# WARNING: f2 has been deprecated from the CEC 2017 benchmark suite
#
# Function 2 optimization complete:
# Mean fitness: 11016915456694810517064180565094623608832.000000
# Median fitness: 2980949995633126659670277752151343104.000000
# Best fitness: 3163098684622379352756060160.000000
# Worst fitness: 107349588150740151615875697493716479508480.000000
# Standard deviation: 32119138671810841985082822599560220639232.000000
# Best distance from optimum (ERROR): 3163098684622379352756060160.000000 / 3.163099E+27
# Worst distance from optimum (ERROR): 107349588150740151615875697493716479508480.000000 / 1.073496E+41
# Mean distance from optimum (ERROR): 11016915456694810517064180565094623608832.000000 / 1.101692E+40
# Median distance from optimum (ERROR): 2980949995633126659670277752151343104.000000 / 2.980950E+36
# STD distance distance from optimum (ERROR): 32119138671810841985082822599560220639232.000000 / 3.211914E+40
# Testing Function 3
#
# Function 3 optimization complete:
# Mean fitness: 126613.997029
# Median fitness: 77362.373384
# Best fitness: 32144.433534
# Worst fitness: 293581.604432
# Standard deviation: 91456.962417
# Best distance from optimum (ERROR): 31844.433534 / 3.184443E+04
# Worst distance from optimum (ERROR): 293281.604432 / 2.932816E+05
# Mean distance from optimum (ERROR): 126313.997029 / 1.263140E+05
# Median distance from optimum (ERROR): 77062.373384 / 7.706237E+04
# STD distance distance from optimum (ERROR): 91456.962417 / 9.145696E+04
# Testing Function 4
#
# Function 4 optimization complete:
# Mean fitness: 4114.349536
# Median fitness: 2978.183665
# Best fitness: 965.480852
# Worst fitness: 12746.011823
# Standard deviation: 3499.619845
# Best distance from optimum (ERROR): 565.480852 / 5.654809E+02
# Worst distance from optimum (ERROR): 12346.011823 / 1.234601E+04
# Mean distance from optimum (ERROR): 3714.349536 / 3.714350E+03
# Median distance from optimum (ERROR): 2578.183665 / 2.578184E+03
# STD distance distance from optimum (ERROR): 3499.619845 / 3.499620E+03
# Testing Function 5
#
# Function 5 optimization complete:
# Mean fitness: 734.723380
# Median fitness: 718.718956
# Best fitness: 645.525144
# Worst fitness: 831.235787
# Standard deviation: 51.778646
# Best distance from optimum (ERROR): 145.525144 / 1.455251E+02
# Worst distance from optimum (ERROR): 331.235787 / 3.312358E+02
# Mean distance from optimum (ERROR): 234.723380 / 2.347234E+02
# Median distance from optimum (ERROR): 218.718956 / 2.187190E+02
# STD distance distance from optimum (ERROR): 51.778646 / 5.177865E+01
# Testing Function 6
#
# Function 6 optimization complete:
# Mean fitness: 666.354381
# Median fitness: 662.467516
# Best fitness: 624.934587
# Worst fitness: 731.575361
# Standard deviation: 28.969054
# Best distance from optimum (ERROR): 24.934587 / 2.493459E+01
# Worst distance from optimum (ERROR): 131.575361 / 1.315754E+02
# Mean distance from optimum (ERROR): 66.354381 / 6.635438E+01
# Median distance from optimum (ERROR): 62.467516 / 6.246752E+01
# STD distance distance from optimum (ERROR): 28.969054 / 2.896905E+01
# Testing Function 7
#
# Function 7 optimization complete:
# Mean fitness: 1198.949018
# Median fitness: 1134.371771
# Best fitness: 1018.136865
# Worst fitness: 1374.579817
# Standard deviation: 132.673954
# Best distance from optimum (ERROR): 318.136865 / 3.181369E+02
# Worst distance from optimum (ERROR): 674.579817 / 6.745798E+02
# Mean distance from optimum (ERROR): 498.949018 / 4.989490E+02
# Median distance from optimum (ERROR): 434.371771 / 4.343718E+02
# STD distance distance from optimum (ERROR): 132.673954 / 1.326740E+02
# Testing Function 8
#
# Function 8 optimization complete:
# Mean fitness: 1025.116335
# Median fitness: 1009.618989
# Best fitness: 885.722779
# Worst fitness: 1169.112969
# Standard deviation: 75.699750
# Best distance from optimum (ERROR): 85.722779 / 8.572278E+01
# Worst distance from optimum (ERROR): 369.112969 / 3.691130E+02
# Mean distance from optimum (ERROR): 225.116335 / 2.251163E+02
# Median distance from optimum (ERROR): 209.618989 / 2.096190E+02
# STD distance distance from optimum (ERROR): 75.699750 / 7.569975E+01
# Testing Function 9
#
# Function 9 optimization complete:
# Mean fitness: 5886.219624
# Median fitness: 4146.864865
# Best fitness: 3424.753286
# Worst fitness: 13178.946388
# Standard deviation: 3199.614076
# Best distance from optimum (ERROR): 2524.753286 / 2.524753E+03
# Worst distance from optimum (ERROR): 12278.946388 / 1.227895E+04
# Mean distance from optimum (ERROR): 4986.219624 / 4.986220E+03
# Median distance from optimum (ERROR): 3246.864865 / 3.246865E+03
# STD distance distance from optimum (ERROR): 3199.614076 / 3.199614E+03
# Testing Function 10
#
# Function 10 optimization complete:
# Mean fitness: 6123.863469
# Median fitness: 5893.126851
# Best fitness: 4594.745122
# Worst fitness: 8426.429826
# Standard deviation: 966.003416
# Best distance from optimum (ERROR): 3594.745122 / 3.594745E+03
# Worst distance from optimum (ERROR): 7426.429826 / 7.426430E+03
# Mean distance from optimum (ERROR): 5123.863469 / 5.123863E+03
# Median distance from optimum (ERROR): 4893.126851 / 4.893127E+03
# STD distance distance from optimum (ERROR): 966.003416 / 9.660034E+02

# %%
def surface_plot_1(function, domain=(-100,100), points=30, dimension=2, ax=None):
    # create points^2 tuples of (x,y) and populate z
    xys = np.linspace(domain[0], domain[1], points)
    xys = np.transpose([np.tile(xys, len(xys)), np.repeat(xys, len(xys))])

    if dimension > 2:
        # concatenate remaining zeros
        tail = np.zeros((xys.shape[0], dimension - 2))
        x = np.concatenate([xys, tail], axis=1)
        zs = function(x)
    else:
        zs = function(xys)
    fig = plt.figure()
    ax = fig.gca(projection='3d')

    X = xys[:,0].reshape((points, points))
    Y = xys[:,1].reshape((points, points))
    Z = zs.reshape((points, points))
    surf = ax.plot_surface(X, Y, Z, cmap='plasma') #, edgecolor='none')
    cbar = fig.colorbar(surf, shrink=0.5, aspect=5, pad=0.15, label='')
    ax.set_title(function.__name__)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')

    # Set the axis color to match the background color
    ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))

    # Set the background color
    ax.set_facecolor((1.0, 1.0, 1.0, 0.0))
    plt.show()
    
    return fig

# %%
def contour_plot_1(function, domain=(-100,100), points=30, ax=None, dimension=2):
    # create points^2 tuples of (x,y) and populate z
    xys = np.linspace(domain[0], domain[1], points)
    xys = np.transpose([np.tile(xys, len(xys)), np.repeat(xys, len(xys))])

    if dimension > 2:
        # concatenate remaining zeros
        tail = np.zeros((xys.shape[0], dimension - 2))
        x = np.concatenate([xys, tail], axis=1)
        zs = function(x)
    else:
        zs = function(xys)

    fig = plt.figure()
    ax = fig.gca()

    X = xys[:,0].reshape((points, points))
    Y = xys[:,1].reshape((points, points))
    Z = zs.reshape((points, points))
    cont = ax.contourf(X, Y, Z, lw = 1, levels=20, cmap='plasma')
    ax.contour(X, Y, Z, colors="k", linestyles="solid")
    cbar = fig.colorbar(cont, shrink=0.5, aspect=5, pad=0.15, label='')
#     cbar = fig.colorbar(ax.collections[0], shrink=0.5, aspect=5, pad=0.15, label='')

    ax.set_title(function.__name__)
    ax.set_xlabel('x')
    ax.set_ylabel('y')

    # Set the background color
    ax.set_facecolor((1.0, 1.0, 1.0, 0.0))
    plt.show()
    
    return fig

# %%
def surface_plot_2(function, domain=(-100,100), points=30, dimension=2, ax=None):
    # create points^2 tuples of (x,y) and populate z
    xys = np.linspace(domain[0], domain[1], points)
    xys = np.transpose([np.tile(xys, len(xys)), np.repeat(xys, len(xys))])

    if dimension > 2:
        # concatenate remaining zeros
        tail = np.zeros((xys.shape[0], dimension - 2))
        x = np.concatenate([xys, tail], axis=1)
        zs = function(x)
    else:
        zs = function(xys)

    fig = plt.figure()
    ax = fig.gca(projection='3d')

    X = xys[:,0].reshape((points, points))
    Y = xys[:,1].reshape((points, points))
    Z = zs.reshape((points, points))

    # plot surface
    surf = ax.plot_surface(X, Y, Z, cmap='plasma') #, edgecolor='none')
    ax.contour(X, Y, Z, zdir='z', cmap="plasma", linestyles="solid", offset=40)
    ax.contour(X, Y, Z, zdir='z', colors="k", linestyles="solid")
    cbar = fig.colorbar(surf, shrink=0.5, aspect=5, pad=0.15, label='')
    ax.set_title(function.__name__)

    # plot contour
    ax.contour(X, Y, Z, levels=10, cmap='plasma')
    
    ax.set_title(function.__name__)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('y')

    # Set the background color
    ax.set_facecolor((1.0, 1.0, 1.0, 0.0))
    plt.show()
    
    return fig

# %%
Dim = 100
NP = 10
bound = 100

# %%
for f in functions.all_functions:
    surface_plot_2(f, points=120, dimension=Dim)

# %%
for f in functions.all_functions:
    contour_plot_1(f, points=120, dimension=Dim)
